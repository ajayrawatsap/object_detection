# %% [markdown]
# <a href="https://colab.research.google.com/github/ajayrawatsap/object_detection/blob/master/pothole_yolo3_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download code files and dataset

# %%
# %%bash
# git clone https://github.com/experiencor/keras-yolo3
# Out:
# Cloning into 'keras-yolo3'...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/ML/pothole_detection/train_data.zip' '/content/'
# !unzip 'train_data.zip' -d  '/content/'

# %%
# %%bash
# pip show keras
# pip show tensorflow

# %% [markdown]
# ## Download Weights

# %%
import os
os.chdir('/content/keras-yolo3')
# !wget https://s3-ap-southeast-1.amazonaws.com/deeplearning-mat/backend.h5
import tensorflow as tf
print(tf.__version__)
# Out:
# --2019-11-02 13:10:00--  https://s3-ap-southeast-1.amazonaws.com/deeplearning-mat/backend.h5
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.124.34
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.124.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248671664 (237M) [application/x-www-form-urlencoded]
# Saving to: ‘backend.h5’
#
# backend.h5          100%[===================>] 237.15M  13.6MB/s    in 19s
#
# 2019-11-02 13:10:20 (12.5 MB/s) - ‘backend.h5’ saved [248671664/248671664]
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %% [markdown]
# ## Change the config file

# %%
import json
with open("zoo/config_raccoon.json", "r") as jsonFile:
    data = json.load(jsonFile)
data['model']['labels'] = ['pothole']

#use script in next cell to generate anchors
# data['model']['anchors'] = [11,10, 13,18, 17,12, 20,18, 22,26, 26,47, 30,20, 38,33, 58,52]
data['model']['anchors'] = [ 11,10, 12,17, 17,12, 21,26, 24,18, 29,52, 36,31, 50,44, 63,63]

data['train']['train_image_folder'] = '/content/train_data/train_images/'
data['train']['train_annot_folder'] = '/content/train_data/train_annot/'



data['valid']['valid_image_folder'] = '/content/train_data/valid_images/'
data['valid']['valid_annot_folder'] = '/content/train_data/valid_annot/'
data['valid']['cache_name'] = 'road_valid.pkl'

data['train']['cache_name'] = 'pothole_train.pkl'
data['train']['nb_epochs'] = 60
data['train']['gpus'] = '0'
data['train']["batch_size"] = 8
data['train']['saved_weights_name'] = 'road.h5'
with open("config.json", "w") as jsonFile:
    json.dump(data, jsonFile)

# %%
# !python gen_anchors.py -c config.json

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## Train

# %%
#! /usr/bin/env python



import os
os.chdir('/content/keras-yolo3')
import argparse

import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from callbacks import CustomModelCheckpoint, CustomTensorBoard
from utils.multi_gpu_model import multi_gpu_model
import tensorflow as tf
import keras
from keras.models import load_model

tf.logging.set_verbosity(tf.logging.ERROR)


def create_training_instances(
    train_annot_folder,
    train_image_folder,
    train_cache,
    valid_annot_folder,
    valid_image_folder,
    valid_cache,
    labels,
):
    # parse annotations of the training set
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)

    # parse annotations of the validation set, if any, otherwise split the training set
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_valid_split = int(0.8*len(train_ints))
        np.random.seed(0)
        np.random.shuffle(train_ints)
        np.random.seed()

        valid_ints = train_ints[train_valid_split:]
        train_ints = train_ints[:train_valid_split]

    # compare the seen labels with the given labels in config.json
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t'  + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels in the config.json.')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        labels = train_labels.keys()
    print('test', train_ints)
    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image

def create_callbacks(saved_weights_name, tensorboard_logs, model_to_save):
    makedirs(tensorboard_logs)
    
    early_stop = EarlyStopping(
        monitor     = 'val_loss', 
        min_delta   = 0.01, 
        patience    = 10, 
        mode        = 'min', 
        verbose     = 1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save   = model_to_save,
        filepath        = saved_weights_name,# + '{epoch:02d}.h5', 
        monitor         = 'val_loss', 
        verbose         = 1, 
        save_best_only  = True, 
        mode            = 'min', 
        period          = 1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor  = 'loss',
        factor   = 0.1,
        patience = 2,
        verbose  = 1,
        mode     = 'min',
        epsilon  = 0.01,
        cooldown = 0,
        min_lr   = 0
    )
    tensorboard = CustomTensorBoard(
        log_dir                = tensorboard_logs,
        write_graph            = True,
        write_images           = True,
    )    
    return [early_stop, checkpoint, reduce_on_plateau, tensorboard]

def create_model(
    nb_class, 
    anchors, 
    max_box_per_image, 
    max_grid, batch_size, 
    warmup_batches, 
    ignore_thresh, 
    multi_gpu, 
    saved_weights_name, 
    lr,
    grid_scales,
    obj_scale,
    noobj_scale,
    xywh_scale,
    class_scale  
):
    if multi_gpu > 1:
        with tf.device('/cpu:0'):
            template_model, infer_model = create_yolov3_model(
                nb_class            = nb_class, 
                anchors             = anchors, 
                max_box_per_image   = max_box_per_image, 
                max_grid            = max_grid, 
                batch_size          = batch_size//multi_gpu, 
                warmup_batches      = warmup_batches,
                ignore_thresh       = ignore_thresh,
                grid_scales         = grid_scales,
                obj_scale           = obj_scale,
                noobj_scale         = noobj_scale,
                xywh_scale          = xywh_scale,
                class_scale         = class_scale
            )
    else:
        template_model, infer_model = create_yolov3_model(
            nb_class            = nb_class, 
            anchors             = anchors, 
            max_box_per_image   = max_box_per_image, 
            max_grid            = max_grid, 
            batch_size          = batch_size, 
            warmup_batches      = warmup_batches,
            ignore_thresh       = ignore_thresh,
            grid_scales         = grid_scales,
            obj_scale           = obj_scale,
            noobj_scale         = noobj_scale,
            xywh_scale          = xywh_scale,
            class_scale         = class_scale
        )  

    # load the pretrained weight if exists, otherwise load the backend weight only
    if os.path.exists(saved_weights_name): 
        print("\nLoading pretrained weights.\n")
        template_model.load_weights(saved_weights_name)
    else:
        template_model.load_weights("backend.h5", by_name=True)       

    if multi_gpu > 1:
        train_model = multi_gpu_model(template_model, gpus=multi_gpu)
    else:
        train_model = template_model      

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)             

    return train_model, infer_model

def _main_(config_path):
    config_path = config_path

    with open(config_path) as config_buffer:    
        config = json.loads(config_buffer.read())

    ###############################
    #   Parse the annotations 
    ###############################
    train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['train']['cache_name'],
        config['valid']['valid_annot_folder'],
        config['valid']['valid_image_folder'],
        config['valid']['cache_name'],
        config['model']['labels']
    )
    print('\nTraining on: \t' + str(labels) + '\n')

    ###############################
    #   Create the generators 
    ###############################    
    train_generator = BatchGenerator(
        instances           = train_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.3, 
        norm                = normalize
    )
    
    valid_generator = BatchGenerator(
        instances           = valid_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.0, 
        norm                = normalize
    )

    ###############################
    #   Create the model 
    ###############################
    if os.path.exists(config['train']['saved_weights_name']): 
        config['train']['warmup_epochs'] = 0
    warmup_batches = config['train']['warmup_epochs'] * (config['train']['train_times']*len(train_generator))   

    os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']
    multi_gpu = len(config['train']['gpus'].split(','))

    train_model, infer_model = create_model(
        nb_class            = len(labels), 
        anchors             = config['model']['anchors'], 
        max_box_per_image   = max_box_per_image, 
        max_grid            = [config['model']['max_input_size'], config['model']['max_input_size']], 
        batch_size          = config['train']['batch_size'], 
        warmup_batches      = warmup_batches,
        ignore_thresh       = config['train']['ignore_thresh'],
        multi_gpu           = multi_gpu,
        saved_weights_name  = config['train']['saved_weights_name'],
        lr                  = config['train']['learning_rate'],
        grid_scales         = config['train']['grid_scales'],
        obj_scale           = config['train']['obj_scale'],
        noobj_scale         = config['train']['noobj_scale'],
        xywh_scale          = config['train']['xywh_scale'],
        class_scale         = config['train']['class_scale'],
    )

    ###############################
    #   Kick off the training
    ###############################
    callbacks = create_callbacks(config['train']['saved_weights_name'], config['train']['tensorboard_dir'], infer_model)
    print('Training started',multi_gpu)
    train_model.fit_generator(
        generator        = train_generator, 
        steps_per_epoch  = len(train_generator) * config['train']['train_times'], 
        epochs           = config['train']['nb_epochs'] + config['train']['warmup_epochs'], 
        verbose          = 1 ,#2 if config['train']['debug'] else 1,
        callbacks        = callbacks, 
        validation_data = valid_generator,
        validation_steps = len(valid_generator),
        workers          = 4,
        max_queue_size   = 8
    )
    print('Multi GPU',multi_gpu) 
    # make a GPU version of infer_model for evaluation
    if multi_gpu > 1:
        infer_model = load_model(config['train']['saved_weights_name'])

    ###############################
    #   Run the evaluation
    ###############################   
    # compute mAP for all the classes

    average_precisions = evaluate(infer_model, valid_generator)

    # print the score
    for label, average_precision in average_precisions.items():
        print(labels[label] + ': {:.4f}'.format(average_precision))
    print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))           

if __name__ == '__main__':
#    argparser = argparse.ArgumentParser(description='train and evaluate YOLO_v3 model on any dataset')
#    argparser.add_argument('-c', '--conf', help='path to configuration file')   

#    args = argparser.parse_args()
    config_path = 'config.json'
    _main_(config_path)
# Out:
# Using TensorFlow backend.
# Seen labels: 	{'pothole': 450}
#
# Given labels: 	['pothole']
# test [{'object': [{'name': 'pothole', 'xmin': 843, 'ymin': 501, 'xmax': 884, 'ymax': 523}, {'name': 'pothole', 'xmin': 447, 'ymin': 486, 'xmax': 491, 'ymax': 509}], 'filename': '/content/train_data/train_images/scene00421.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 432, 'ymin': 474, 'xmax': 539, 'ymax': 533}], 'filename': '/content/train_data/train_images/scene00436.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 599, 'ymin': 471, 'xmax': 730, 'ymax': 522}, {'name': 'pothole', 'xmin': 623, 'ymin': 413, 'xmax': 689, 'ymax': 443}], 'filename': '/content/train_data/train_images/scene00601.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 627, 'ymin': 498, 'xmax': 706, 'ymax': 538}, {'name': 'pothole', 'xmin': 665, 'ymin': 433, 'xmax': 691, 'ymax': 460}, {'name': 'pothole', 'xmin': 630, 'ymin': 404, 'xmax': 695, 'ymax': 428}], 'filename': '/content/train_data/train_images/scene00616.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 542, 'ymin': 575, 'xmax': 637, 'ymax': 633}, {'name': 'pothole', 'xmin': 560, 'ymin': 513, 'xmax': 641, 'ymax': 567}, {'name': 'pothole', 'xmin': 579, 'ymin': 479, 'xmax': 639, 'ymax': 509}, {'name': 'pothole', 'xmin': 584, 'ymin': 453, 'xmax': 639, 'ymax': 475}, {'name': 'pothole', 'xmin': 600, 'ymin': 432, 'xmax': 654, 'ymax': 454}], 'filename': '/content/train_data/train_images/scene00646.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 571, 'ymin': 471, 'xmax': 614, 'ymax': 493}, {'name': 'pothole', 'xmin': 596, 'ymin': 440, 'xmax': 649, 'ymax': 466}], 'filename': '/content/train_data/train_images/scene00676.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 542, 'ymin': 490, 'xmax': 600, 'ymax': 534}], 'filename': '/content/train_data/train_images/scene00691.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 631, 'ymin': 502, 'xmax': 688, 'ymax': 529}, {'name': 'pothole', 'xmin': 642, 'ymin': 435, 'xmax': 680, 'ymax': 449}, {'name': 'pothole', 'xmin': 644, 'ymin': 412, 'xmax': 676, 'ymax': 433}, {'name': 'pothole', 'xmin': 638, 'ymin': 393, 'xmax': 671, 'ymax': 407}], 'filename': '/content/train_data/train_images/scene00766.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 598, 'ymin': 509, 'xmax': 694, 'ymax': 592}], 'filename': '/content/train_data/train_images/scene00781.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 660, 'ymin': 423, 'xmax': 694, 'ymax': 440}], 'filename': '/content/train_data/train_images/scene00841.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 737, 'ymin': 386, 'xmax': 781, 'ymax': 407}], 'filename': '/content/train_data/train_images/scene01831.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 698, 'ymin': 388, 'xmax': 813, 'ymax': 440}], 'filename': '/content/train_data/train_images/scene01966.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 813, 'ymin': 447, 'xmax': 860, 'ymax': 480}, {'name': 'pothole', 'xmin': 750, 'ymin': 422, 'xmax': 803, 'ymax': 439}, {'name': 'pothole', 'xmin': 724, 'ymin': 398, 'xmax': 786, 'ymax': 420}], 'filename': '/content/train_data/train_images/scene02116.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 831, 'ymin': 469, 'xmax': 917, 'ymax': 523}, {'name': 'pothole', 'xmin': 913, 'ymin': 542, 'xmax': 997, 'ymax': 579}], 'filename': '/content/train_data/train_images/scene02131.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 907, 'ymin': 502, 'xmax': 978, 'ymax': 538}, {'name': 'pothole', 'xmin': 826, 'ymin': 451, 'xmax': 931, 'ymax': 501}, {'name': 'pothole', 'xmin': 803, 'ymin': 436, 'xmax': 843, 'ymax': 446}, {'name': 'pothole', 'xmin': 764, 'ymin': 409, 'xmax': 828, 'ymax': 434}], 'filename': '/content/train_data/train_images/scene02161.jpg', 'width': 12 ...
#
# Training on: 	['pothole']
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1335: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Training started 1
# Epoch 1/63
# resizing:  resizing: 416  384416
# 384
#  1/84 [..............................] - ETA: 44:59 - loss: 1594.8722 - yolo_layer_1_loss: 218.3893 - yolo_layer_2_loss: 452.0573 - yolo_layer_3_loss: 924.4257resizing:  352 352
#  5/84 [>.............................] - ETA: 9:59 - loss: 1489.9312 - yolo_layer_1_loss: 198.6744 - yolo_layer_2_loss: 418.0683 - yolo_layer_3_loss: 873.1885 resizing:  320 320
# 27/84 [========>.....................] - ETA: 2:21 - loss: 957.8505 - yolo_layer_1_loss: 127.5335 - yolo_layer_2_loss: 264.8169 - yolo_layer_3_loss: 565.5001resizing:  288 288
# 43/84 [==============>...............] - ETA: 1:19 - loss: 744.4784 - yolo_layer_1_loss: 100.9562 - yolo_layer_2_loss: 204.9669 - yolo_layer_3_loss: 438.5554resizing:  384 384
# 46/84 [===============>..............] - ETA: 1:10 - loss: 714.4295 - yolo_layer_1_loss: 97.1264 - yolo_layer_2_loss: 196.5608 - yolo_layer_3_loss: 420.7423resizing:  384 384
# 55/84 [==================>...........] - ETA: 51s - loss: 643.2143 - yolo_layer_1_loss: 88.1095 - yolo_layer_2_loss: 176.6821 - yolo_layer_3_loss: 378.4227resizing:  448 448
# resizing:  288 288
# 60/84 [====================>.........] - ETA: 43s - loss: 613.9927 - yolo_layer_1_loss: 84.5052 - yolo_layer_2_loss: 168.3704 - yolo_layer_3_loss: 361.1171resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss:
# 83/84 [============================>.] - ETA: 1s - loss: 24.5334 - yolo_layer_1_loss: 4.3623 - yolo_layer_2_loss: 7.0960 - yolo_layer_3_loss: 13.0751resizing:  448 448
# resizing:  352 352
# 84/84 [==============================] - 93s 1s/step - loss: 24.5531 - yolo_layer_1_loss: 4.3716 - yolo_layer_2_loss: 7.0856 - yolo_layer_3_loss: 13.0960 - val_loss: 22.2186 - val_yolo_layer_1_loss: 3.9857 - val_yolo_layer_2_loss: 6.7845 - val_yolo_layer_3_loss: 11.4484
#
# Epoch 00004: val_loss improved from 32.80596 to 22.21862, saving model to road.h5
# Epoch 5/63
#  2/84 [..............................] - ETA: 1:26 - loss: 17.1074 - yolo_layer_1_loss: 2.6265 - yolo_layer_2_loss: 3.3300 - yolo_layer_3_loss: 11.1509resizing:  448 448
# 10/84 [==>...........................] - ETA: 1:39 - loss: 23.6103 - yolo_layer_1_loss: 6.5368 - yolo_layer_2_loss: 6.1602 - yolo_layer_3_loss: 10.9133resizing:  448 448
# 27/84 [========>.....................] - ETA: 1:20 - loss: 24.4459 - yolo_layer_1_loss: 6.5920 - yolo_layer_2_loss: 7.1533 - yolo_layer_3_loss: 10.7005resizing:  384 384
# resizing:  448 448
# 41/84 [=============>................] - ETA: 1:00 - loss: 23.4596 - yolo_layer_1_loss: 6.3758 - yolo_layer_2_loss: 6.7423 - yolo_layer_3_loss: 10.3415resizing:  416 416
# 60/84 [====================>.........] - ETA: 33s - loss: 22.9332 - yolo_layer_1_loss: 6.3191 - yolo_layer_2_loss: 6.3663 - yolo_layer_3_loss: 10.2478resizing:  352 352
# 61/84 [====================>.........] - ETA: 32s - loss: 22.9328 - yolo_layer_1_loss: 6.2981 - yolo_layer_2_loss: 6.3905 - yolo_layer_3_loss: 10.2442resizing:  352 352
# 70/84 [========================>.....] - ETA: 19s - loss: 23.0436 - yolo_layer_1_loss: 6.4965 - yolo_layer_2_loss: 6.3500 - yolo_layer_3_loss: 10.1972resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 22.1217 - yolo_layer_1_loss: 6.0468 - yolo_layer_2_loss: 6.0581 - yolo_layer_3_loss: 10.0168resizing:  352 352
# resizing:  448 448
# 84/84 [==============================] - 114s 1s/step - loss: 22.0682 - yolo_layer_1_loss: 5.9825 - yolo_layer_2_loss: 6.0739 - yolo_layer_3_loss: 10.0118 - val_loss: 17.4018 - val_yolo_layer_1_loss: 2.4539 - val_yolo_layer_2_loss: 5.0204 - val_yolo_layer_3_loss: 9.9275
#
# Epoch 00005: val_loss improved from 22.21862 to 17.40182, saving model to road.h5
# Epoch 6/63
#  4/84 [>.............................] - ETA: 1:16 - loss: 16.9054 - yolo_layer_1_loss: 2.6550 - yolo_layer_2_loss: 4.8131 - yolo_layer_3_loss: 9.4373resizing:  384 384
# 16/84 [====>.........................] - ETA: 1:11 - loss: 19.7188 - yolo_layer_1_loss: 4.1640 - yolo_layer_2_loss: 5.2126 - yolo_layer_3_loss: 10.3421resizing:  320 320
izing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 14.8855 - yolo_layer_1_loss: 2.8620 - yolo_layer_2_loss: 3.9385 - yolo_layer_3_loss: 8.0850resizing:  288 288
# resizing:  384 384
# 84/84 [==============================] - 107s 1s/step - loss: 14.9082 - yolo_layer_1_loss: 2.8804 - yolo_layer_2_loss: 3.9485 - yolo_layer_3_loss: 8.0793 - val_loss: 15.0462 - val_yolo_layer_1_loss: 2.7611 - val_yolo_layer_2_loss: 4.8295 - val_yolo_layer_3_loss: 7.4556
#
# Epoch 00010: val_loss improved from 15.49191 to 15.04620, saving model to road.h5
# Epoch 11/63
#  4/84 [>.............................] - ETA: 1:44 - loss: 16.7703 - yolo_layer_1_loss: 3.8105 - yolo_layer_2_loss: 4.5935 - yolo_layer_3_loss: 8.3664resizing:  416 416
#  6/84 [=>............................] - ETA: 1:29 - loss: 15.2901 - yolo_layer_1_loss: 2.9158 - yolo_layer_2_loss: 3.9584 - yolo_layer_3_loss: 8.4159resizing:  352 352
# 27/84 [========>.....................] - ETA: 59s - loss: 14.5980 - yolo_layer_1_loss: 2.4257 - yolo_layer_2_loss: 3.8376 - yolo_layer_3_loss: 8.3346 resizing:  416 416
# 41/84 [=============>................] - ETA: 46s - loss: 14.7490 - yolo_layer_1_loss: 2.6422 - yolo_layer_2_loss: 3.8524 - yolo_layer_3_loss: 8.2544resizing:  416 416
# 42/84 [==============>...............] - ETA: 45s - loss: 14.7894 - yolo_layer_1_loss: 2.6249 - yolo_layer_2_loss: 3.9069 - yolo_layer_3_loss: 8.2576resizing:  384 384
# 55/84 [==================>...........] - ETA: 32s - loss: 14.7495 - yolo_layer_1_loss: 2.6535 - yolo_layer_2_loss: 3.9629 - yolo_layer_3_loss: 8.1330resizing:  416 416
# resizing:  352 352
# 64/84 [=====================>........] - ETA: 23s - loss: 14.6260 - yolo_layer_1_loss: 2.6483 - yolo_layer_2_loss: 3.9427 - yolo_layer_3_loss: 8.0350resizing:  384 384
# 83/84 [============================>.] - ETA: 1s - loss: 14.5370 - yolo_layer_1_loss: 2.6510 - yolo_layer_2_loss: 3.8626 - yolo_layer_3_loss: 8.0234resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# 84/84 [==============================] - 99s 1s/step - loss: 14.4867 - yolo_layer_1_loss: 2.6418 - yolo_layer_2_loss: 3.8457 - yolo_layer_3_loss: 7.9993 - val_loss: 14.7996 - val_yolo_layer_1_loss: 2.9960 - val_yolo_layer_2_loss: 4.1073 - val_yolo_layer_3_loss: 7.6962
#
# Epoch 00011: val_loss improved from 15.04620 to 14.79956, saving model to road.h5
# Epoch 12/63
# 15/84 [====>.........................] - ETA: 1:16 - loss: 14.7932 - yolo_layer_1_loss: 2.3199 - yolo_layer_2_loss: 3.9730 - yolo_layer_3_loss: 8.5003resizing:  352 352
# 27/84 [========>.....................] - ETA: 1:02 - loss: 14.7237 - yolo_layer_1_loss: 2.4457 - yolo_layer_2_loss: 3.8406 - yolo_layer_3_loss: 8.4373resizing:  320 320
# 30/84 [=========>....................] - ETA: 58s - loss: 14.4878 - yolo_layer_1_loss: 2.3190 - yolo_layer_2_loss: 3.6796 - yolo_layer_3_loss: 8.4892resizing:  352 352
# 36/84 [===========>..................] - ETA: 50s - loss: 14.4576 - yolo_layer_1_loss: 2.3534 - yolo_layer_2_loss: 3.7878 - yolo_layer_3_loss: 8.3164resizing:  448 448
# 55/84 [==================>...........] - ETA: 32s - loss: 14.4475 - yolo_layer_1_loss: 2.5426 - yolo_layer_2_loss: 3.7792 - yolo_layer_3_loss: 8.1258resizing:  384 384
# 65/84 [======================>.......] - ETA: 21s - loss: 14.4337 - yolo_layer_1_loss: 2.6488 - yolo_layer_2_loss: 3.7518 - yolo_layer_3_loss: 8.0330resizing:  352 352
# 71/84 [========================>.....] - ETA: 14s - loss: 14.4496 - yolo_layer_1_loss: 2.6537 - yolo_layer_2_loss: 3.7821 - yolo_layer_3_loss: 8.0138resizing:  288 288
# 83/84 [============================>.] - ETA: 1s - loss: 14.3224 - yolo_layer_1_loss: 2.5166 - yolo_layer_2_loss: 3.8061 - yolo_layer_3_loss: 7.9997resizing:  288 288
# 84/84 [==============================] - 98s 1s/step - loss: 14.2835 - yolo_layer_1_loss: 2.4873 - yolo_layer_2_loss: 3.8024 - yolo_layer_3_loss: 7.9937 - val_loss: 15.5872 - val_yolo_layer_1_loss: 4.0923 - val_yolo_layer_2_loss: 3.7560 - val_yolo_layer_3_loss: 7.7389
#
# Epoch 00012: val_loss did not improve from 14.79956
# Epoch 13/63
#  8/84 [=>............................] - ETA: 1:03 - loss: 12.0437 - yolo_layer_1_loss: 1.1122 - yolo_layer_2_loss: 2.5074 - yolo_layer_3_loss: 8.4241resizing:  320 320
# 17/84 [=====>........................] - ETA: 55s - loss: 12.8826 - yolo_layer_1_loss: 1.5848 - yolo_layer_2_loss: 2.7761 - yolo_layer_3_loss: 8.5217resizing:  416 416
# 18/84 [=====>........................] - ETA: 55s - loss: 13.3136 - yolo_layer_1_loss: 1.6509 - yolo_layer_2_loss: 3.0105 - yolo_layer_3_loss: 8.6523resizing:  352 352
# 27/84 [========>.....................] - ETA: 50s - loss: 13.5127 - yolo_layer_1_loss: 1.9516 - yolo_layer_2_loss: 3.0335 - yolo_layer_3_loss: 8.5276resizing:  448 448
# resizing:  384 384
# 39/84 [============>.................] - ETA: 44s - loss: 13.5944 - yolo_layer_1_loss: 2.2255 - yolo_layer_2_loss: 3.2596 - yolo_layer_3_loss: 8.1094resizing:  352 352
# 55/84 [==================>...........] - ETA: 29s - loss: 13.7554 - yolo_layer_1_loss: 2.3288 - yolo_layer_2_loss: 3.3805 - yolo_layer_3_loss: 8.0461resizing:  352 352
# resizing:  384 384
# 74/84 [=========================>....] - ETA: 10s - loss: 13.5869 - yolo_layer_1_loss: 2.1376 - yolo_layer_2_loss: 3.5323 - yolo_layer_3_loss: 7.9170resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss:
# Epoch 00014: val_loss improved from 13.64864 to 13.18934, saving model to road.h5
# Epoch 15/63
#  4/84 [>.............................] - ETA: 1:13 - loss: 12.8864 - yolo_layer_1_loss: 1.9963 - yolo_layer_2_loss: 2.6013 - yolo_layer_3_loss: 8.2887resizing:  320 320
# 11/84 [==>...........................] - ETA: 1:03 - loss: 12.9364 - yolo_layer_1_loss: 1.1852 - yolo_layer_2_loss: 3.4963 - yolo_layer_3_loss: 8.2548resizing:  288 288
# 28/84 [=========>....................] - ETA: 48s - loss: 12.4894 - yolo_layer_1_loss: 1.3693 - yolo_layer_2_loss: 3.0706 - yolo_layer_3_loss: 8.0495resizing:  352 352
# 31/84 [==========>...................] - ETA: 46s - loss: 12.7555 - yolo_layer_1_loss: 1.4352 - yolo_layer_2_loss: 3.2410 - yolo_layer_3_loss: 8.0793resizing:  352 352
# 40/84 [=============>................] - ETA: 38s - loss: 12.2898 - yolo_layer_1_loss: 1.3307 - yolo_layer_2_loss: 3.0299 - yolo_layer_3_loss: 7.9293resizing:  384 384
# 56/84 [===================>..........] - ETA: 26s - loss: 12.7526 - yolo_layer_1_loss: 1.6419 - yolo_layer_2_loss: 3.2851 - yolo_layer_3_loss: 7.8256resizing:  448 448
# 61/84 [====================>.........] - ETA: 22s - loss: 12.8012 - yolo_layer_1_loss: 1.7095 - yolo_layer_2_loss: 3.3054 - yolo_layer_3_loss: 7.7863resizing:  320 320
# 74/84 [=========================>....] - ETA: 10s - loss: 12.7088 - yolo_layer_1_loss: 1.8092 - yolo_layer_2_loss: 3.3124 - yolo_layer_3_loss: 7.5873resizing:  448 448
# 83/84 [============================>.] - ETA: 0s - loss: 12.7942 - yolo_layer_1_loss: 1.8376 - yolo_layer_2_loss: 3.2751 - yolo_layer_3_loss: 7.6815resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# 84/84 [==============================] - 87s 1s/step - loss: 12.8326 - yolo_layer_1_loss: 1.8817 - yolo_layer_2_loss: 3.2909 - yolo_layer_3_loss: 7.6600 - val_loss: 17.3297 - val_yolo_layer_1_loss: 2.8252 - val_yolo_layer_2_loss: 6.0736 - val_yolo_layer_3_loss: 8.4308
#
# Epoch 00015: val_loss did not improve from 13.18934
# Epoch 16/63
#  9/84 [==>...........................] - ETA: 1:39 - loss: 14.0639 - yolo_layer_1_loss: 3.5321 - yolo_layer_2_loss: 3.8216 - yolo_layer_3_loss: 6.7101resizing:  352 352
# 27/84 [========>.....................] - ETA: 1:01 - loss: 12.8633 - yolo_layer_1_loss: 2.2845 - yolo_layer_2_loss: 3.3228 - yolo_layer_3_loss: 7.2560resizing:  448 448
# 39/84 [============>.................] - ETA: 51s - loss: 13.0349 - yolo_layer_1_loss: 2.3935 - yolo_layer_2_loss: 3.4819 - yolo_layer_3_loss: 7.1595resizing:  384 384
# 45/84 [===============>..............] - ETA: 46s - loss: 13.2359 - yolo_layer_1_loss: 2.5177 - yolo_layer_2_loss: 3.4529 - yolo_layer_3_loss: 7.2653resizing:  288 288
h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 18/63
# resizing:  352 352
#  4/84 [>.............................] - ETA: 1:25 - loss: 11.0080 - yolo_layer_1_loss: 1.4530 - yolo_layer_2_loss: 3.1118 - yolo_layer_3_loss: 6.4431resizing:  288 288
# 16/84 [====>.........................] - ETA: 1:09 - loss: 12.4006 - yolo_layer_1_loss: 1.7802 - yolo_layer_2_loss: 3.3785 - yolo_layer_3_loss: 7.2420resizing:  416 416
# 27/84 [========>.....................] - ETA: 55s - loss: 11.6226 - yolo_layer_1_loss: 1.6231 - yolo_layer_2_loss: 2.9801 - yolo_layer_3_loss: 7.0194resizing:  448 448
# 29/84 [=========>....................] - ETA: 55s - loss: 11.5058 - yolo_layer_1_loss: 1.5582 - yolo_layer_2_loss: 2.9512 - yolo_layer_3_loss: 6.9963resizing:  352 352
# 41/84 [=============>................] - ETA: 47s - loss: 11.8126 - yolo_layer_1_loss: 1.8109 - yolo_layer_2_loss: 3.1852 - yolo_layer_3_loss: 6.8165resizing:  320 320
# 55/84 [==================>...........] - ETA: 31s - loss: 11.5569 - yolo_layer_1_loss: 1.7337 - yolo_layer_2_loss: 3.0775 - yolo_layer_3_loss: 6.7457resizing:  384 384
# 60/84 [====================>.........] - ETA: 25s - loss: 11.6547 - yolo_layer_1_loss: 1.8011 - yolo_layer_2_loss: 3.0928 - yolo_layer_3_loss: 6.7608resizing:  288 288
# 73/84 [=========================>....] - ETA: 11s - loss: 11.4717 - yolo_layer_1_loss: 1.7830 - yolo_layer_2_loss: 2.9466 - yolo_layer_3_loss: 6.7420resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 11.5493 - yolo_layer_1_loss: 1.6823 - yolo_layer_2_loss: 2.9262 - yolo_layer_3_loss: 6.9408resizing:  352 352
# resizing:  352 352
# 84/84 [==============================] - 89s 1s/step - loss: 11.5502 - yolo_layer_1_loss: 1.6827 - yolo_layer_2_loss: 2.9045 - yolo_layer_3_loss: 6.9630 - val_loss: 11.3603 - val_yolo_layer_1_loss: 0.8075 - val_yolo_layer_2_loss: 2.2022 - val_yolo_layer_3_loss: 8.3506
#
# Epoch 00018: val_loss did not improve from 11.14899
# Epoch 19/63
#  3/84 [>.............................] - ETA: 1:58 - loss: 12.0345 - yolo_layer_1_loss: 2.3527 - yolo_layer_2_loss: 2.9087 - yolo_layer_3_loss: 6.7730resizing:  384 384
# 17/84 [=====>........................] - ETA: 1:23 - loss: 12.0678 - yolo_layer_1_loss: 2.0428 - yolo_layer_2_loss: 3.0858 - yolo_layer_3_loss: 6.9392resizing:  448 448
# 27/84 [========>.....................] - ETA: 1:09 - loss: 11.8640 - yolo_layer_1_loss: 2.1353 - yolo_layer_2_loss: 3.0285 - yolo_layer_3_loss: 6.7003resizing:  416 416
# 32/84 [==========>...................] - ETA: 1:05 - loss: 11.9696 - yolo_layer_1_loss: 2.1243 - yolo_layer_2_loss: 3.1468 - yolo_layer_3_loss: 6.6985resizing:  448 448
# 46/84 [===============>..............] - ETA: 49s - loss: 12.0279 - yolo_layer_1_loss: 2.1961 - yolo_layer_2_loss: 3.2664 - yolo_layer_3_loss: 6.5653resizing:  352 352
# 55/84 [==================>...........] - ETA: 38s - loss: 12.3012 - yolo_layer_1_loss: 2.3089 - yolo_layer_2_loss: 3.3259 - yolo_layer_3_loss: 6.6664resizing:  288 288
# resizing:  352 352
# 64/84 [=====================>........] - ETA: 25s - loss: 12.1801 - yolo_layer_1_loss: 2.2359 - yolo_layer_2_loss: 3.2208 - yolo_layer_3_loss: 6.7234resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 11.8923 - yolo_layer_1_loss: 1.9828 - yolo_layer_2_loss: 3.0638 - yolo_layer_3_loss: 6.8457resizing:  416 416
# 84/84 [==============================] - 103s 1s/step - loss: 11.8075 - yolo_layer_1_loss: 1.9599 - yolo_layer_2_loss: 3.0292 - yolo_layer_3_loss: 6.8184 - val_loss: 12.4910 - val_yolo_layer_1_loss: 0.7311 - val_yolo_layer_2_loss: 2.9210 - val_yolo_layer_3_loss: 8.8388
#
# Epoch 00019: val_loss did not improve from 11.14899
# Epoch 20/63
#  4/84 [>.............................] - ETA: 1:13 - loss: 13.2118 - yolo_layer_1_loss: 0.8634 - yolo_layer_2_loss: 2.9044 - yolo_layer_3_loss: 9.4440resizing:  288 288
# 10/84 [==>...........................] - ETA: 1:07 - loss: 12.0738 - yolo_layer_1_loss: 1.4454 - yolo_layer_2_loss: 3.1527 - yolo_layer_3_loss: 7.4757resizing:  288 288
# 13/84 [===>..........................] - ETA: 1:05 - loss: 11.9940 - yolo_layer_1_loss: 1.2130 - yolo_layer_2_loss: 3.1680 - yolo_layer_3_loss: 7.6129resizing:  352 352
# 27/84 [========>.....................] - ETA: 52s - loss: 11.3943 - yolo_layer_1_loss: 1.3345 - yolo_layer_2_loss: 2.6876 - yolo_layer_3_loss: 7.3723resizing:  416 416
# 34/84 [===========>..................] - ETA: 49s - loss: 11.2985 - yolo_layer_1_loss: 1.3730 - yolo_layer_2_loss: 2.7250 - yolo_layer_3_loss: 7.2005resizing:  320 320
# 37/84 [============>.................] - ETA: 47s - loss: 11.0954 - yolo_layer_1_loss: 1.3782 - yolo_layer_2_loss: 2.6884 - yolo_layer_3_loss: 7.0288resizing:  448 448
# 55/84 [==================>...........] - ETA: 32s - loss: 11.6155 - yolo_layer_1_loss: 1.7958 - yolo_layer_2_loss: 2.9891 - yolo_layer_3_loss: 6.8306resizing:  352 352
# resizing:  384 384
# 61/84 [====================>.........] - ETA: 26s - loss: 11.6997 - yolo_layer_1_loss: 1.8041 - yolo_layer_2_loss: 3.0589 - yolo_layer_3_loss: 6.8368resizing:  416 416
# 83/84 [============================>.] - ETA: 1s - loss: 11.7051 - yolo_layer_1_loss: 1.8721 - yolo_layer_2_loss: 3.0541 - yolo_layer_3_loss: 6.7789resizing:  288 288
# resizing:  416 416
# 84/84 [==============================] - 102s 1s/step - loss: 11.6822 - yolo_layer_1_loss: 1.8582 - yolo_layer_2_loss: 3.0460 - yolo_layer_3_loss: 6.7780 - val_loss: 14.6754 - val_yolo_layer_1_loss: 2.1333 - val_yolo_layer_2_loss: 4.7658 - val_yolo_layer_3_loss: 7.7762
#
# Epoch 00020: val_loss did not improve from 11.14899
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 21/63
#  3/84 [>.............................] - ETA: 1:49 - loss: 13.8434 - yolo_layer_1_loss: 1.9370 - yolo_layer_2_loss: 4.3328 - yolo_layer_3_loss: 7.5736resizing:  448 448
#  5/84 [>.............................] - ETA: 1:38 - loss: 14.1420 - yolo_layer_1_loss: 1.6773 - yolo_layer_2_loss: 4.7671 - yolo_layer_3_loss: 7.6976resizing:  320 320
# 27/84 [========>.....................] - ETA: 56s - loss: 11.6593 - yolo_layer_1_loss: 1.3970 - yolo_layer_2_loss: 3.2045 - yolo_layer_3_loss: 7.0579resizing:  352 352
# 29/84 [=========>....................] - ETA: 54s - loss: 11.4797 - yolo_layer_1_loss: 1.3203 - yolo_layer_2_loss: 3.1076 - yolo_layer_3_loss: 7.0519resizing:  288 288
# 36/84 [===========>..................] - ETA: 47s - loss: 11.6074 - yolo_layer_1_loss: 1.5402 - yolo_layer_2_loss: 3.0980 - yolo_layer_3_loss: 6.9692resizing:  448 448
# 65/84 [======================>.......] - ETA: 21s - loss: 11.8159 - yolo_layer_1_loss: 1.6755 - yolo_layer_2_loss: 3.2714 - yolo_layer_3_loss: 6.8690resizing:  288 288
# 68/84 [=======================>......] - ETA: 18s - loss: 11.9078 - yolo_layer_1_loss: 1.7088 - yolo_layer_2_loss: 3.2886 - yolo_layer_3_loss: 6.9104resizing:  288 288
# 73/84 [=========================>....] - ETA: 12s - loss: 11.9028 - yolo_layer_1_loss: 1.7326 - yolo_layer_2_loss: 3.3069 - yolo_layer_3_loss: 6.8632resizing:  416 416
# 83/84 [============================>.] - ETA: 1s - loss: 11.8423 - yolo_layer_1_loss: 1.7108 - yolo_layer_2_loss: 3.1796 - yolo_layer_3_loss: 6.9518resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# 84/84 [==============================] - 99s 1s/step - loss: 11.8468 - yolo_layer_1_loss: 1.7090 - yolo_layer_2_loss: 3.2018 - yolo_layer_3_loss: 6.9360 - val_loss: 16.1343 - val_yolo_layer_1_loss: 2.5869 - val_yolo_layer_2_loss: 4.4836 - val_yolo_layer_3_loss: 9.0638
#
# Epoch 00021: val_loss did not improve from 11.14899
# Epoch 22/63
#  1/84 [..............................] - ETA: 1:10 - loss: 10.7431 - yolo_layer_1_loss: 1.2807 - yolo_layer_2_loss: 1.9069 - yolo_layer_3_loss: 7.5555resizing:  320 320
# 33/84 [==========>...................] - ETA: 49s - loss: 10.7594 - yolo_layer_1_loss: 1.7017 - yolo_layer_2_loss: 2.3258 - yolo_layer_3_loss: 6.7318resizing:  320 320
# 35/84 [===========>..................] - ETA: 47s - loss: 10.6814 - yolo_layer_1_loss: 1.6525 - yolo_layer_2_loss: 2.3616 - yolo_layer_3_loss: 6.6672resizing:  320 320
# 36/84 [===========>..................] - ETA: 46s - loss: 10.6108 - yolo_layer_1_loss: 1.6141 - yolo_layer_2_loss: 2.3539 - yolo_layer_3_loss: 6.6428resizing:  320 320
# 55/84 [==================>...........] - ETA: 27s - loss: 10.9035 - yolo_layer_1_loss: 1.3827 - yolo_layer_2_loss: 2.5118 - yolo_layer_3_loss: 7.0089resizing:  320 320
# 64/84 [=====================>........] - ETA: 18s - loss: 11.0857 - yolo_layer_1_loss: 1.4276 - yolo_layer_2_loss: 2.5997 - yolo_layer_3_loss: 7.0585resizing:  288 288
# 69/84 [=======================>......] - ETA: 14s - loss: 10.9803 - yolo_layer_1_loss: 1.3886 - yolo_layer_2_loss: 2.5675 - yolo_layer_3_loss: 7.0242resizing:  320 320
# 83/84 [============================>.] - ETA: 0s - loss: 10.8449 - yolo_layer_1_loss: 1.3188 - yolo_layer_2_loss: 2.6016 - yolo_layer_3_loss: 6.9245resizing:  416 416
# resizing:  448 448
# 84/84 [==============================] - 81s 968ms/step - loss: 10.8760 - yolo_layer_1_loss: 1.3182 - yolo_layer_2_loss: 2.6048 - yolo_layer_3_loss: 6.9530 - val_loss: 14.5085 - val_yolo_layer_1_loss: 3.1131 - val_yolo_layer_2_loss: 3.7403 - val_yolo_layer_3_loss: 7.6550
#
# Epoch 00022: val_loss did not improve from 11.14899
# Epoch 23/63
#  9/84 [==>...........................] - ETA: 1:19 - loss: 12.6429 - yolo_layer_1_loss: 2.6154 - yolo_layer_2_loss: 2.7030 - yolo_layer_3_loss: 7.3245resizing:  288 288
# 11/84 [==>...........................] - ETA: 1:21 - loss: 12.9065 - yolo_layer_1_loss: 2.7586 - yolo_layer_2_loss: 3.1659 - yolo_layer_3_loss: 6.9821resizing:  448 448
# 27/84 [========>.....................] - ETA: 1:10 - loss: 11.9840 - yolo_layer_1_loss: 2.3639 - yolo_layer_2_loss: 3.2231 - yolo_layer_3_loss: 6.3970resizing:  448 448
# 42/84 [==============>...............] - ETA: 55s - loss: 11.8895 - yolo_layer_1_loss: 2.0648 - yolo_layer_2_loss: 3.4229 - yolo_layer_3_loss: 6.4018resizing:  352 352
# 44/84 [==============>...............] - ETA: 53s - loss: 11.9740 - yolo_layer_1_loss: 2.1504 - yolo_layer_2_loss: 3.4769 - yolo_layer_3_loss: 6.3466resizing:  416 416
# 60/84 [====================>.........] - ETA: 32s - loss: 12.4047 - yolo_layer_1_loss: 2.3514 - yolo_layer_2_loss: 3.4862 - yolo_layer_3_loss: 6.5671resizing:  288 288
# 65/84 [======================>.......] - ETA: 25s - loss: 12.3337 - yolo_layer_1_loss: 2.3012 - yolo_layer_2_loss: 3.4716 - yolo_layer_3_loss: 6.5609resizing:  320 320
# 73/84 [=========================>....] - ETA: 14s - loss: 12.0430 - yolo_layer_1_loss: 2.1803 - yolo_layer_2_loss: 3.3243 - yolo_layer_3_loss: 6.5384resizing:  384 384
# 83/84 [============================>.] - ETA: 1s - loss: 11.8665 - yolo_layer_1_loss: 2.0841 - yolo_layer_2_loss: 3.2486 - yolo_layer_3_loss: 6.5337resizing:  352 352
# resizing:  288 288
# 84/84 [==============================] - 109s 1s/step - loss: 11.8704 - yolo_layer_1_loss: 2.0801 - yolo_layer_2_loss: 3.2629 - yolo_layer_3_loss: 6.5274 - val_loss: 12.6481 - val_yolo_layer_1_loss: 1.5702 - val_yolo_layer_2_loss: 3.8638 - val_yolo_layer_3_loss: 7.2141
#
# Epoch 00023: val_loss did not improve from 11.14899
# Epoch 24/63
#  8/84 [=>............................] - ETA: 1:27 - loss: 10.4180 - yolo_layer_1_loss: 1.5211 - yolo_layer_2_loss: 2.3839 - yolo_layer_3_loss: 6.5130resizing:  448 448
# 16/84 [====>.........................] - ETA: 1:15 - loss: 10.5133 - yolo_layer_1_loss: 1.2876 - yolo_layer_2_loss: 2.5054 - yolo_layer_3_loss: 6.7204resizing:  352 352
# 27/84 [========>.....................] - ETA: 1:08 - loss: 11.3490 - yolo_layer_1_loss: 1.9808 - yolo_layer_2_loss: 2.8027 - yolo_layer_3_loss: 6.5656resizing:  288 288
# 35/84 [===========>..................] - ETA: 56s - loss: 10.6435 - yolo_layer_1_loss: 1.6494 - yolo_layer_2_loss: 2.5357 - yolo_layer_3_loss: 6.4584resizing:  416 416
# 36/84 [===========>..................] - ETA: 55s - loss: 10.6139 - yolo_layer_1_loss: 1.6060 - yolo_layer_2_loss: 2.5376 - yolo_layer_3_loss: 6.4702resizing:  384 384
# 55/84 [==================>...........] - ETA: 32s - loss: 10.9289 - yolo_layer_1_loss: 1.6721 - yolo_layer_2_loss: 2.5796 - yolo_layer_3_loss: 6.6772resizing:  320 320
# 62/84 [=====================>........] - ETA: 24s - loss: 11.0705 - yolo_layer_1_loss: 1.6814 - yolo_layer_2_loss: 2.6442 - yolo_layer_3_loss: 6.7448resizing:  288 288
# 72/84 [========================>.....] - ETA: 12s - loss: 11.1726 - yolo_layer_1_loss: 1.7129 - yolo_layer_2_loss: 2.7568 - yolo_layer_3_loss: 6.7028resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 11.0835 - yolo_layer_1_loss: 1.6245 - yolo_layer_2_loss: 2.6822 - yolo_layer_3_loss: 6.7768resizing:  320 320
# 84/84 [==============================] - 91s 1s/step - loss: 11.0555 - yolo_layer_1_loss: 1.6058 - yolo_layer_2_loss: 2.6701 - yolo_layer_3_loss: 6.7796 - val_loss: 13.5035 - val_yolo_layer_1_loss: 1.8519 - val_yolo_layer_2_loss: 3.8348 - val_yolo_layer_3_loss: 7.8168
#
# Epoch 00024: val_loss did not improve from 11.14899
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 25/63
# resizing:  448 448
#  5/84 [>.............................] - ETA: 1:13 - loss: 10.2792 - yolo_layer_1_loss: 2.1246 - yolo_layer_2_loss: 2.2696 - yolo_layer_3_loss: 5.8850resizing:  448 448
# 16/84 [====>.........................] - ETA: 1:18 - loss: 11.5040 - yolo_layer_1_loss: 2.3041 - yolo_layer_2_loss: 3.1375 - yolo_layer_3_loss: 6.0625resizing:  320 320
# 27/84 [========>.....................] - ETA: 1:10 - loss: 11.3297 - yolo_layer_1_loss: 2.2947 - yolo_layer_2_loss: 2.9983 - yolo_layer_3_loss: 6.0367resizing:  352 352
# 30/84 [=========>....................] - ETA: 1:05 - loss: 11.4599 - yolo_layer_1_loss: 2.2196 - yolo_layer_2_loss: 2.9565 - yolo_layer_3_loss: 6.2838resizing:  352 352
# 33/84 [==========>...................] - ETA: 1:00 - loss: 11.3546 - yolo_layer_1_loss: 2.0910 - yolo_layer_2_loss: 2.8056 - yolo_layer_3_loss: 6.4580resizing:  352 352
# 56/84 [===================>..........] - ETA: 31s - loss: 10.8144 - yolo_layer_1_loss: 1.6606 - yolo_layer_2_loss: 2.4377 - yolo_layer_3_loss: 6.7161resizing:  288 288
# 61/84 [====================>.........] - ETA: 25s - loss: 10.9295 - yolo_layer_1_loss: 1.7268 - yolo_layer_2_loss: 2.4469 - yolo_layer_3_loss: 6.7559resizing:  288 288
# 66/84 [======================>.......] - ETA: 20s - loss: 11.0055 - yolo_layer_1_loss: 1.7245 - yolo_layer_2_loss: 2.5180 - yolo_layer_3_loss: 6.7630resizing:  352 352
# 83/84 [============================>.] - ETA: 1s - loss: 10.8494 - yolo_layer_1_loss: 1.5981 - yolo_layer_2_loss: 2.4667 - yolo_layer_3_loss: 6.7846resizing:  352 352
# resizing:  352 352
# 84/84 [==============================] - 93s 1s/step - loss: 10.8539 - yolo_layer_1_loss: 1.5990 - yolo_layer_2_loss: 2.4742 - yolo_layer_3_loss: 6.7807 - val_loss: 12.8881 - val_yolo_layer_1_loss: 0.5957 - val_yolo_layer_2_loss: 3.9873 - val_yolo_layer_3_loss: 8.3051
#
# Epoch 00025: val_loss did not improve from 11.14899
# Epoch 26/63
#  2/84 [..............................] - ETA: 1:27 - loss: 13.1449 - yolo_layer_1_loss: 4.3758 - yolo_layer_2_loss: 3.2019 - yolo_layer_3_loss: 5.5672resizing:  384 384
# 18/84 [=====>........................] - ETA: 1:12 - loss: 11.5055 - yolo_layer_1_loss: 1.9374 - yolo_layer_2_loss: 2.8706 - yolo_layer_3_loss: 6.6975resizing:  384 384
# 27/84 [========>.....................] - ETA: 1:03 - loss: 11.2068 - yolo_layer_1_loss: 1.7738 - yolo_layer_2_loss: 2.6099 - yolo_layer_3_loss: 6.8231resizing:  448 448
# 36/84 [===========>..................] - ETA: 55s - loss: 11.3735 - yolo_layer_1_loss: 1.7726 - yolo_layer_2_loss: 2.8269 - yolo_layer_3_loss: 6.7740resizing:  320 320
# 40/84 [=============>................] - ETA: 52s - loss: 11.6732 - yolo_layer_1_loss: 1.7115 - yolo_layer_2_loss: 2.9847 - yolo_layer_3_loss: 6.9769resizing:  448 448
# 58/84 [===================>..........] - ETA: 32s - loss: 11.6269 - yolo_layer_1_loss: 1.8545 - yolo_layer_2_loss: 3.0525 - yolo_layer_3_loss: 6.7199resizing:  448 448
# 65/84 [======================>.......] - ETA: 23s - loss: 11.7934 - yolo_layer_1_loss: 2.0196 - yolo_layer_2_loss: 3.1484 - yolo_layer_3_loss: 6.6253resizing:  448 448
# 69/84 [=======================>......] - ETA: 19s - loss: 11.9412 - yolo_layer_1_loss: 2.0670 - yolo_layer_2_loss: 3.2382 - yolo_layer_3_loss: 6.6360resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 11.9238 - yolo_layer_1_loss: 2.1389 - yolo_layer_2_loss: 3.2296 - yolo_layer_3_loss: 6.5552resizing:  416 416
# resizing:  288 288
# 84/84 [==============================] - 112s 1s/step - loss: 11.9313 - yolo_layer_1_loss: 2.1286 - yolo_layer_2_loss: 3.2560 - yolo_layer_3_loss: 6.5467 - val_loss: 13.6446 - val_yolo_layer_1_loss: 1.7225 - val_yolo_layer_2_loss: 3.6220 - val_yolo_layer_3_loss: 8.3002
#
# Epoch 00026: val_loss did not improve from 11.14899
# Epoch 27/63
#  3/84 [>.............................] - ETA: 1:56 - loss: 14.7017 - yolo_layer_1_loss: 2.6233 - yolo_layer_2_loss: 5.5934 - yolo_layer_3_loss: 6.4850resizing:  352 352
#  4/84 [>.............................] - ETA: 1:53 - loss: 14.7166 - yolo_layer_1_loss: 3.3007 - yolo_layer_2_loss: 5.3253 - yolo_layer_3_loss: 6.0906resizing:  416 416
# 27/84 [========>.....................] - ETA: 1:16 - loss: 12.1796 - yolo_layer_1_loss: 1.8049 - yolo_layer_2_loss: 3.7919 - yolo_layer_3_loss: 6.5827resizing:  320 320
# resizing:  416 416
# 43/84 [==============>...............] - ETA: 54s - loss: 12.2485 - yolo_layer_1_loss: 1.9983 - yolo_layer_2_loss: 3.5242 - yolo_layer_3_loss: 6.7260resizing:  288 288
# 69/84 [=======================>......] - ETA: 18s - loss: 11.8379 - yolo_layer_1_loss: 1.6700 - yolo_layer_2_loss: 3.2528 - yolo_layer_3_loss: 6.9151resizing:  448 448
# 71/84 [========================>.....] - ETA: 15s - loss: 11.7837 - yolo_layer_1_loss: 1.6243 - yolo_layer_2_loss: 3.1955 - yolo_layer_3_loss: 6.9639resizing:  448 448
# 74/84 [=========================>....] - ETA: 11s - loss: 11.7561 - yolo_layer_1_loss: 1.5623 - yolo_layer_2_loss: 3.1663 - yolo_layer_3_loss: 7.0275resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 11.8063 - yolo_layer_1_loss: 1.6425 - yolo_layer_2_loss: 3.1170 - yolo_layer_3_loss: 7.0467resizing:  352 352
# 84/84 [==============================] - 101s 1s/step - loss: 11.7819 - yolo_layer_1_loss: 1.6305 - yolo_layer_2_loss: 3.0954 - yolo_layer_3_loss: 7.0560 - val_loss: 12.5257 - val_yolo_layer_1_loss: 1.3635 - val_yolo_layer_2_loss: 2.5188 - val_yolo_layer_3_loss: 8.6434
#
# Epoch 00027: val_loss did not improve from 11.14899
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 00027: early stopping
# Multi GPU 1
# pothole: 0.6024
# mAP: 0.6024
