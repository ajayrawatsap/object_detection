# %% [markdown]
# <a href="https://colab.research.google.com/github/ajayrawatsap/object_detection/blob/master/pothole_yolo3_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download code files and dataset

# %%
# %%bash
# git clone https://github.com/experiencor/keras-yolo3
# Out:
# Cloning into 'keras-yolo3'...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/ML/pothole_detection/train_data.zip' '/content/'
# !unzip 'train_data.zip' -d  '/content/'

# %%
# %%bash
# pip show keras
# pip show tensorflow

# %% [markdown]
# ## Download Weights

# %%
import os
os.chdir('/content/keras-yolo3')
# !wget https://s3-ap-southeast-1.amazonaws.com/deeplearning-mat/backend.h5
import tensorflow as tf
print(tf.__version__)
# Out:
# --2019-11-02 08:15:26--  https://s3-ap-southeast-1.amazonaws.com/deeplearning-mat/backend.h5
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.128.2
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.128.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248671664 (237M) [application/x-www-form-urlencoded]
# Saving to: ‘backend.h5’
#
# backend.h5          100%[===================>] 237.15M  13.6MB/s    in 19s
#
# 2019-11-02 08:15:46 (12.3 MB/s) - ‘backend.h5’ saved [248671664/248671664]
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %% [markdown]
# ## Change the config file

# %%
import json
with open("zoo/config_raccoon.json", "r") as jsonFile:
    data = json.load(jsonFile)
data['model']['labels'] = ['pothole']

#use script in next cell to generate anchors
# data['model']['anchors'] = [11,10, 13,18, 17,12, 20,18, 22,26, 26,47, 30,20, 38,33, 58,52]
data['model']['anchors'] = [ 11,10, 12,17, 17,12, 21,26, 24,18, 29,52, 36,31, 50,44, 63,63]

data['train']['train_image_folder'] = '/content/train_data/train_images/'
data['train']['train_annot_folder'] = '/content/train_data/train_annot/'



data['valid']['valid_image_folder'] = '/content/train_data/valid_images/'
data['valid']['valid_annot_folder'] = '/content/train_data/valid_annot/'
data['valid']['cache_name'] = 'road_valid.pkl'

data['train']['cache_name'] = 'pothole_train.pkl'
data['train']['nb_epochs'] = 50
data['train']['gpus'] = '0'
data['train']["batch_size"] = 8
data['train']['saved_weights_name'] = 'road.h5'
with open("config.json", "w") as jsonFile:
    json.dump(data, jsonFile)

# %%
# !python gen_anchors.py -c config.json

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## Train

# %%
#! /usr/bin/env python



import os
os.chdir('/content/keras-yolo3')
import argparse

import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from callbacks import CustomModelCheckpoint, CustomTensorBoard
from utils.multi_gpu_model import multi_gpu_model
import tensorflow as tf
import keras
from keras.models import load_model

tf.logging.set_verbosity(tf.logging.ERROR)


def create_training_instances(
    train_annot_folder,
    train_image_folder,
    train_cache,
    valid_annot_folder,
    valid_image_folder,
    valid_cache,
    labels,
):
    # parse annotations of the training set
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)

    # parse annotations of the validation set, if any, otherwise split the training set
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_valid_split = int(0.8*len(train_ints))
        np.random.seed(0)
        np.random.shuffle(train_ints)
        np.random.seed()

        valid_ints = train_ints[train_valid_split:]
        train_ints = train_ints[:train_valid_split]

    # compare the seen labels with the given labels in config.json
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t'  + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels in the config.json.')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        labels = train_labels.keys()
    print('test', train_ints)
    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image

def create_callbacks(saved_weights_name, tensorboard_logs, model_to_save):
    makedirs(tensorboard_logs)
    
    early_stop = EarlyStopping(
        monitor     = 'loss', 
        min_delta   = 0.01, 
        patience    = 5, 
        mode        = 'min', 
        verbose     = 1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save   = model_to_save,
        filepath        = saved_weights_name,# + '{epoch:02d}.h5', 
        monitor         = 'loss', 
        verbose         = 1, 
        save_best_only  = True, 
        mode            = 'min', 
        period          = 1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor  = 'loss',
        factor   = 0.1,
        patience = 2,
        verbose  = 1,
        mode     = 'min',
        epsilon  = 0.01,
        cooldown = 0,
        min_lr   = 0
    )
    tensorboard = CustomTensorBoard(
        log_dir                = tensorboard_logs,
        write_graph            = True,
        write_images           = True,
    )    
    return [early_stop, checkpoint, reduce_on_plateau, tensorboard]

def create_model(
    nb_class, 
    anchors, 
    max_box_per_image, 
    max_grid, batch_size, 
    warmup_batches, 
    ignore_thresh, 
    multi_gpu, 
    saved_weights_name, 
    lr,
    grid_scales,
    obj_scale,
    noobj_scale,
    xywh_scale,
    class_scale  
):
    if multi_gpu > 1:
        with tf.device('/cpu:0'):
            template_model, infer_model = create_yolov3_model(
                nb_class            = nb_class, 
                anchors             = anchors, 
                max_box_per_image   = max_box_per_image, 
                max_grid            = max_grid, 
                batch_size          = batch_size//multi_gpu, 
                warmup_batches      = warmup_batches,
                ignore_thresh       = ignore_thresh,
                grid_scales         = grid_scales,
                obj_scale           = obj_scale,
                noobj_scale         = noobj_scale,
                xywh_scale          = xywh_scale,
                class_scale         = class_scale
            )
    else:
        template_model, infer_model = create_yolov3_model(
            nb_class            = nb_class, 
            anchors             = anchors, 
            max_box_per_image   = max_box_per_image, 
            max_grid            = max_grid, 
            batch_size          = batch_size, 
            warmup_batches      = warmup_batches,
            ignore_thresh       = ignore_thresh,
            grid_scales         = grid_scales,
            obj_scale           = obj_scale,
            noobj_scale         = noobj_scale,
            xywh_scale          = xywh_scale,
            class_scale         = class_scale
        )  

    # load the pretrained weight if exists, otherwise load the backend weight only
    if os.path.exists(saved_weights_name): 
        print("\nLoading pretrained weights.\n")
        template_model.load_weights(saved_weights_name)
    else:
        template_model.load_weights("backend.h5", by_name=True)       

    if multi_gpu > 1:
        train_model = multi_gpu_model(template_model, gpus=multi_gpu)
    else:
        train_model = template_model      

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)             

    return train_model, infer_model

def _main_(config_path):
    config_path = config_path

    with open(config_path) as config_buffer:    
        config = json.loads(config_buffer.read())

    ###############################
    #   Parse the annotations 
    ###############################
    train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['train']['cache_name'],
        config['valid']['valid_annot_folder'],
        config['valid']['valid_image_folder'],
        config['valid']['cache_name'],
        config['model']['labels']
    )
    print('\nTraining on: \t' + str(labels) + '\n')

    ###############################
    #   Create the generators 
    ###############################    
    train_generator = BatchGenerator(
        instances           = train_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.3, 
        norm                = normalize
    )
    
    valid_generator = BatchGenerator(
        instances           = valid_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.0, 
        norm                = normalize
    )

    ###############################
    #   Create the model 
    ###############################
    if os.path.exists(config['train']['saved_weights_name']): 
        config['train']['warmup_epochs'] = 0
    warmup_batches = config['train']['warmup_epochs'] * (config['train']['train_times']*len(train_generator))   

    os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']
    multi_gpu = len(config['train']['gpus'].split(','))

    train_model, infer_model = create_model(
        nb_class            = len(labels), 
        anchors             = config['model']['anchors'], 
        max_box_per_image   = max_box_per_image, 
        max_grid            = [config['model']['max_input_size'], config['model']['max_input_size']], 
        batch_size          = config['train']['batch_size'], 
        warmup_batches      = warmup_batches,
        ignore_thresh       = config['train']['ignore_thresh'],
        multi_gpu           = multi_gpu,
        saved_weights_name  = config['train']['saved_weights_name'],
        lr                  = config['train']['learning_rate'],
        grid_scales         = config['train']['grid_scales'],
        obj_scale           = config['train']['obj_scale'],
        noobj_scale         = config['train']['noobj_scale'],
        xywh_scale          = config['train']['xywh_scale'],
        class_scale         = config['train']['class_scale'],
    )

    ###############################
    #   Kick off the training
    ###############################
    callbacks = create_callbacks(config['train']['saved_weights_name'], config['train']['tensorboard_dir'], infer_model)
    print('Training started')
    train_model.fit_generator(
        generator        = train_generator, 
        steps_per_epoch  = len(train_generator) * config['train']['train_times'], 
        epochs           = config['train']['nb_epochs'] + config['train']['warmup_epochs'], 
        verbose          = 1 ,#2 if config['train']['debug'] else 1,
        callbacks        = callbacks, 
        validation_data = valid_generator,
        validation_steps = len(valid_generator),
        workers          = 4,
        max_queue_size   = 8
    )
     
    # make a GPU version of infer_model for evaluation
    if multi_gpu > 1:
        infer_model = load_model(config['train']['saved_weights_name'])

    ###############################
    #   Run the evaluation
    ###############################   
    # compute mAP for all the classes
    average_precisions = evaluate(infer_model, valid_generator)

    # print the score
    for label, average_precision in average_precisions.items():
        print(labels[label] + ': {:.4f}'.format(average_precision))
    print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))           

if __name__ == '__main__':
#    argparser = argparse.ArgumentParser(description='train and evaluate YOLO_v3 model on any dataset')
#    argparser.add_argument('-c', '--conf', help='path to configuration file')   

#    args = argparser.parse_args()
    config_path = 'config.json'
    _main_(config_path)
# Out:
# Using TensorFlow backend.
# Seen labels: 	{'pothole': 450}
#
# Given labels: 	['pothole']
# test [{'object': [{'name': 'pothole', 'xmin': 843, 'ymin': 501, 'xmax': 884, 'ymax': 523}, {'name': 'pothole', 'xmin': 447, 'ymin': 486, 'xmax': 491, 'ymax': 509}], 'filename': '/content/train_data/train_images/scene00421.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 432, 'ymin': 474, 'xmax': 539, 'ymax': 533}], 'filename': '/content/train_data/train_images/scene00436.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 599, 'ymin': 471, 'xmax': 730, 'ymax': 522}, {'name': 'pothole', 'xmin': 623, 'ymin': 413, 'xmax': 689, 'ymax': 443}], 'filename': '/content/train_data/train_images/scene00601.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 627, 'ymin': 498, 'xmax': 706, 'ymax': 538}, {'name': 'pothole', 'xmin': 665, 'ymin': 433, 'xmax': 691, 'ymax': 460}, {'name': 'pothole', 'xmin': 630, 'ymin': 404, 'xmax': 695, 'ymax': 428}], 'filename': '/content/train_data/train_images/scene00616.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 542, 'ymin': 575, 'xmax': 637, 'ymax': 633}, {'name': 'pothole', 'xmin': 560, 'ymin': 513, 'xmax': 641, 'ymax': 567}, {'name': 'pothole', 'xmin': 579, 'ymin': 479, 'xmax': 639, 'ymax': 509}, {'name': 'pothole', 'xmin': 584, 'ymin': 453, 'xmax': 639, 'ymax': 475}, {'name': 'pothole', 'xmin': 600, 'ymin': 432, 'xmax': 654, 'ymax': 454}], 'filename': '/content/train_data/train_images/scene00646.jpg', 'width': 1280, 'height': 720}, {'object': [{'name': 'pothole', 'xmin': 571, 'ymin': 471, 'xmax': 614, 'ymax': 493}, {'name': 'pothole', 'xmin': 596, 'ymin': 
# 65/84 [======================>.......] - ETA: 24s - loss: 132.1793 - yolo_layer_1_loss: 18.4033 - yolo_layer_2_loss: 32.8659 - yolo_layer_3_loss: 80.9101resizing:  448 448
# 72/84 [========================>.....] - ETA: 15s - loss: 130.3681 - yolo_layer_1_loss: 18.4209 - yolo_layer_2_loss: 32.3824 - yolo_layer_3_loss: 79.5648resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 126.4057 - yolo_layer_1_loss: 18.0549 - yolo_layer_2_loss: 31.3462 - yolo_layer_3_loss: 77.0046resizing:  384 384
# resizing:  320 320
# 84/84 [==============================] - 111s 1s/step - loss: 125.8879 - yolo_layer_1_loss: 17.9948 - yolo_layer_2_loss: 31.2378 - yolo_layer_3_loss: 76.6554 - val_loss: 259.7577 - val_yolo_layer_1_loss: 32.1927 - val_yolo_layer_2_loss: 65.1157 - val_yolo_layer_3_loss: 162.4493
#
# Epoch 00002: loss improved from 587.08955 to 125.88794, saving model to road.h5
# Epoch 3/53
#  5/84 [>.............................] - ETA: 1:19 - loss: 83.9151 - yolo_layer_1_loss: 14.7430 - yolo_layer_2_loss: 19.9052 - yolo_layer_3_loss: 49.2669resizing:  384 384
#  9/84 [==>...........................] - ETA: 1:20 - loss: 86.2910 - yolo_layer_1_loss: 14.6241 - yolo_layer_2_loss: 20.9355 - yolo_layer_3_loss: 50.7314resizing:  352 352
# 34/84 [===========>..................] - ETA: 54s - loss: 82.6447 - yolo_layer_1_loss: 13.8590 - yolo_layer_2_loss: 20.2967 - yolo_layer_3_loss: 48.4890resizing:  320 320
# 43/84 [==============>...............] - ETA: 44s - loss: 81.1633 - yolo_layer_1_loss: 13.7732 - yolo_layer_2_loss: 20.1003 - yolo_layer_3_loss: 47.2898resizing:  416 416
# 46/84 [===============>..............] - ETA: 40s - loss: 80.4224 - yolo_layer_1_loss: 13.6510 - yolo_layer_2_loss: 19.9115 - yolo_layer_3_loss: 46.8599resizing:  320 320
# 55/84 [==================>...........] - ETA: 31s - loss: 79.1069 - yolo_layer_1_loss: 13.3878 - yolo_layer_2_loss: 19.5868 - yolo_layer_3_loss: 46.1324resizing:  320 320
# resizing:  448 448
# 62/84 [=====================>........] - ETA: 23s - loss: 78.0339 - yolo_layer_1_loss: 13.1843 - yolo_layer_2_loss: 19.3601 - yolo_layer_3_loss: 45.4894resizing:  352 352
# 83/84 [============================>.] - ETA: 1s - loss: 72.6540 - yolo_layer_1_loss: 12.0654 - yolo_layer_2_loss: 18.1687 - yolo_layer_3_loss: 42.4199resizing:  352 352
# resizing:  416 416
# 84/84 [==============================] - 94s 1s/step - loss: 72.0620 - yolo_layer_1_loss: 11.9384 - yolo_layer_2_loss: 17.9919 - yolo_layer_3_loss: 42.1317 - val_loss: 37.8711 - val_yolo_layer_1_loss: 3.6686 - val_yolo_layer_2_loss: 8.0736 - val_yolo_layer_3_loss: 26.1289
#
# Epoch 00003: loss improved from 125.88794 to 72.06200, saving model to road.h5
# Epoch 4/53
# 73/84 [=========================>....] - ETA: 11s - loss: 19.1364 - yolo_layer_1_loss: 4.0347 - yolo_layer_2_loss: 4.9897 - yolo_layer_3_loss: 10.1120resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 18.7081 - yolo_layer_1_loss: 3.8621 - yolo_layer_2_loss: 4.8519 - yolo_layer_3_loss: 9.9941 resizing:  384 384
# resizing:  288 288
# 84/84 [==============================] - 91s 1s/step - loss: 18.6703 - yolo_layer_1_loss: 3.8171 - yolo_layer_2_loss: 4.8359 - yolo_layer_3_loss: 10.0173 - val_loss: 20.8601 - val_yolo_layer_1_loss: 4.5498 - val_yolo_layer_2_loss: 6.1661 - val_yolo_layer_3_loss: 10.1442
#
# Epoch 00005: loss improved from 27.09626 to 18.67031, saving model to road.h5
# Epoch 6/53
#  5/84 [>.............................] - ETA: 1:26 - loss: 17.8067 - yolo_layer_1_loss: 4.3222 - yolo_layer_2_loss: 4.7316 - yolo_layer_3_loss: 8.7529resizing:  416 416
# 18/84 [=====>........................] - ETA: 1:17 - loss: 19.7266 - yolo_layer_1_loss: 5.3332 - yolo_layer_2_loss: 4.9266 - yolo_layer_3_loss: 9.4668resizing:  352 352
# 27/84 [========>.....................] - ETA: 1:10 - loss: 20.0041 - yolo_layer_1_loss: 5.6293 - yolo_layer_2_loss: 5.1420 - yolo_layer_3_loss: 9.2328resizing:  384 384
# resizing:  416 416
# 36/84 [===========>..................] - ETA: 58s - loss: 20.3992 - yolo_layer_1_loss: 5.7657 - yolo_layer_2_loss: 5.4564 - yolo_layer_3_loss: 9.1771resizing:  384 384
# 55/84 [==================>...........] - ETA: 35s - loss: 20.1282 - yolo_layer_1_loss: 5.4855 - yolo_layer_2_loss: 5.3265 - yolo_layer_3_loss: 9.3162resizing:  288 288
# 64/84 [=====================>........] - ETA: 24s - loss: 19.7480 - yolo_layer_1_loss: 5.1812 - yolo_layer_2_loss: 5.2444 - yolo_layer_3_loss: 9.3224resizing:  416 416
# 68/84 [=======================>......] - ETA: 18s - loss: 19.4883 - yolo_layer_1_loss: 5.0465 - yolo_layer_2_loss: 5.1651 - yolo_layer_3_loss: 9.2768resizing:  352 352
# 83/84 [============================>.] - ETA: 1s - loss: 19.0328 - yolo_layer_1_loss: 4.7921 - yolo_layer_2_loss: 4.9414 - yolo_layer_3_loss: 9.2993resizing:  384 384
# 84/84 [==============================] - 99s 1s/step - loss: 19.0506 - yolo_layer_1_loss: 4.8000 - yolo_layer_2_loss: 4.9375 - yolo_layer_3_loss: 9.3131 - val_loss: 15.0214 - val_yolo_layer_1_loss: 1.3122 - val_yolo_layer_2_loss: 3.2306 - val_yolo_layer_3_loss: 10.4785
#
# Epoch 00006: loss did not improve from 18.67031
# Epoch 7/53
#  7/84 [=>............................] - ETA: 1:22 - loss: 15.3531 - yolo_layer_1_loss: 3.0445 - yolo_layer_2_loss: 3.8473 - yolo_layer_3_loss: 8.4612resizing:  352 352
#  8/84 [=>............................] - ETA: 1:21 - loss: 16.4148 - yolo_layer_1_loss: 3.5586 - yolo_layer_2_loss: 4.0799 - yolo_layer_3_loss: 8.7762resizing:  384 384
# resizing:  288 288
# 84/84 [==============================] - 91s 1s/step - loss: 15.6396 - yolo_layer_1_loss: 3.0451 - yolo_layer_2_loss: 4.0513 - yolo_layer_3_loss: 8.5432 - val_loss: 14.9807 - val_yolo_layer_1_loss: 2.4447 - val_yolo_layer_2_loss: 4.1375 - val_yolo_layer_3_loss: 8.3985
#
# Epoch 00009: loss improved from 15.97620 to 15.63962, saving model to road.h5
# Epoch 10/53
# 10/84 [==>...........................] - ETA: 1:32 - loss: 14.3950 - yolo_layer_1_loss: 2.7769 - yolo_layer_2_loss: 4.0546 - yolo_layer_3_loss: 7.5635resizing:  448 448
# 15/84 [====>.........................] - ETA: 1:29 - loss: 15.1247 - yolo_layer_1_loss: 2.8495 - yolo_layer_2_loss: 4.1846 - yolo_layer_3_loss: 8.0906resizing:  416 416
# 27/84 [========>.....................] - ETA: 1:16 - loss: 15.8685 - yolo_layer_1_loss: 3.4152 - yolo_layer_2_loss: 4.5359 - yolo_layer_3_loss: 7.9175resizing:  416 416
# 29/84 [=========>....................] - ETA: 1:14 - loss: 15.7986 - yolo_layer_1_loss: 3.4064 - yolo_layer_2_loss: 4.5410 - yolo_layer_3_loss: 7.8512resizing:  352 352
# 38/84 [============>.................] - ETA: 1:02 - loss: 15.7173 - yolo_layer_1_loss: 3.2927 - yolo_layer_2_loss: 4.3749 - yolo_layer_3_loss: 8.0496resizing:  320 320
# 67/84 [======================>.......] - ETA: 20s - loss: 15.1817 - yolo_layer_1_loss: 2.8441 - yolo_layer_2_loss: 4.1681 - yolo_layer_3_loss: 8.1695resizing:  448 448
# 68/84 [=======================>......] - ETA: 18s - loss: 15.1658 - yolo_layer_1_loss: 2.8451 - yolo_layer_2_loss: 4.1515 - yolo_layer_3_loss: 8.1692resizing:  448 448
# 71/84 [========================>.....] - ETA: 15s - loss: 15.2388 - yolo_layer_1_loss: 2.8827 - yolo_layer_2_loss: 4.1050 - yolo_layer_3_loss: 8.2511resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 15.2094 - yolo_layer_1_loss: 2.8056 - yolo_layer_2_loss: 4.1566 - yolo_layer_3_loss: 8.2472resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# 84/84 [==============================] - 100s 1s/step - loss: 15.1688 - yolo_layer_1_loss: 2.7734 - yolo_layer_2_loss: 4.1377 - yolo_layer_3_loss: 8.2577 - val_loss: 13.3896 - val_yolo_layer_1_loss: 1.0297 - val_yolo_layer_2_loss: 2.6924 - val_yolo_layer_3_loss: 9.6676
#
# Epoch 00010: loss improved from 15.63962 to 15.16879, saving model to road.h5
# Epoch 11/53
#  3/84 [>.............................] - ETA: 1:15 - loss: 12.1091 - yolo_layer_1_loss: 1.5014 - yolo_layer_2_loss: 2.1656 - yolo_layer_3_loss: 8.4421resizing:  320 320
# 27/84 [========>.....................] - ETA: 56s - loss: 13.8131 - yolo_layer_1_loss: 2.2265 - yolo_layer_2_loss: 3.3653 - yolo_layer_3_loss: 8.2214resizing:  288 288
# resizing:  448 448
# 67/84 [======================>.......] - ETA: 19s - loss: 13.3228 - yolo_layer_1_loss: 2.4012 - yolo_layer_2_loss: 3.5524 - yolo_layer_3_loss: 7.3693resizing:  320 320
# 74/84 [=========================>....] - ETA: 11s - loss: 13.1818 - yolo_layer_1_loss: 2.3126 - yolo_layer_2_loss: 3.4700 - yolo_layer_3_loss: 7.3993resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 13.1380 - yolo_layer_1_loss: 2.2110 - yolo_layer_2_loss: 3.4859 - yolo_layer_3_loss: 7.4410resizing:  448 448
# resizing:  416 416
# 84/84 [==============================] - 98s 1s/step - loss: 13.1254 - yolo_layer_1_loss: 2.1943 - yolo_layer_2_loss: 3.4900 - yolo_layer_3_loss: 7.4411 - val_loss: 16.0652 - val_yolo_layer_1_loss: 3.0825 - val_yolo_layer_2_loss: 5.0186 - val_yolo_layer_3_loss: 7.9642
#
# Epoch 00015: loss improved from 13.16988 to 13.12541, saving model to road.h5
# Epoch 16/53
#  4/84 [>.............................] - ETA: 1:14 - loss: 15.4555 - yolo_layer_1_loss: 1.3930 - yolo_layer_2_loss: 3.9766 - yolo_layer_3_loss: 10.0858resizing:  288 288
# 11/84 [==>...........................] - ETA: 1:26 - loss: 12.9232 - yolo_layer_1_loss: 1.8699 - yolo_layer_2_loss: 3.5200 - yolo_layer_3_loss: 7.5333resizing:  448 448
# 27/84 [========>.....................] - ETA: 1:07 - loss: 13.0994 - yolo_layer_1_loss: 2.0108 - yolo_layer_2_loss: 3.4423 - yolo_layer_3_loss: 7.6463resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# 57/84 [===================>..........] - ETA: 28s - loss: 12.9582 - yolo_layer_1_loss: 1.7339 - yolo_layer_2_loss: 3.3466 - yolo_layer_3_loss: 7.8777resizing:  320 320
# 70/84 [========================>.....] - ETA: 14s - loss: 12.6732 - yolo_layer_1_loss: 1.5469 - yolo_layer_2_loss: 3.3140 - yolo_layer_3_loss: 7.8124resizing:  288 288
# 72/84 [========================>.....] - ETA: 12s - loss: 12.7095 - yolo_layer_1_loss: 1.5048 - yolo_layer_2_loss: 3.3484 - yolo_layer_3_loss: 7.8563resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 12.7430 - yolo_layer_1_loss: 1.5590 - yolo_layer_2_loss: 3.3211 - yolo_layer_3_loss: 7.8628resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# 84/84 [==============================] - 88s 1s/step - loss: 12.7496 - yolo_layer_1_loss: 1.5725 - yolo_layer_2_loss: 3.3151 - yolo_layer_3_loss: 7.8619 - val_loss: 14.5371 - val_yolo_layer_1_loss: 2.4296 - val_yolo_layer_2_loss: 4.2046 - val_yolo_layer_3_loss: 7.9029
#
# Epoch 00016: loss improved from 13.12541 to 12.74960, saving model to road.h5
# Epoch 17/53
# 15/84 [====>.........................] - ETA: 1:28 - loss: 13.7271 - yolo_layer_1_loss: 2.7751 - yolo_layer_2_loss: 3.6937 - yolo_layer_3_loss: 7.2583resizing:  416 416
# resizing:  384 384
# 84/84 [==============================] - 90s 1s/step - loss: 12.5868 - yolo_layer_1_loss: 1.9828 - yolo_layer_2_loss: 3.2576 - yolo_layer_3_loss: 7.3464 - val_loss: 14.3865 - val_yolo_layer_1_loss: 2.7151 - val_yolo_layer_2_loss: 4.1111 - val_yolo_layer_3_loss: 7.5603
#
# Epoch 00018: loss improved from 12.74960 to 12.58676, saving model to road.h5
# Epoch 19/53
#  1/84 [..............................] - ETA: 1:17 - loss: 12.4233 - yolo_layer_1_loss: 0.8301 - yolo_layer_2_loss: 2.1503 - yolo_layer_3_loss: 9.4428resizing:  416 416
#  2/84 [..............................] - ETA: 1:16 - loss: 13.1360 - yolo_layer_1_loss: 2.1995 - yolo_layer_2_loss: 2.0690 - yolo_layer_3_loss: 8.8675resizing:  288 288
# 27/84 [========>.....................] - ETA: 58s - loss: 11.9908 - yolo_layer_1_loss: 1.9372 - yolo_layer_2_loss: 2.6994 - yolo_layer_3_loss: 7.3543resizing: resizing:   288352  288352
#
# resizing:  352 352
# 55/84 [==================>...........] - ETA: 30s - loss: 12.0627 - yolo_layer_1_loss: 1.9296 - yolo_layer_2_loss: 2.9246 - yolo_layer_3_loss: 7.2086resizing:  288 288
# 57/84 [===================>..........] - ETA: 28s - loss: 12.1364 - yolo_layer_1_loss: 2.0017 - yolo_layer_2_loss: 2.9040 - yolo_layer_3_loss: 7.2306resizing:  384 384
# 61/84 [====================>.........] - ETA: 23s - loss: 11.9363 - yolo_layer_1_loss: 1.9566 - yolo_layer_2_loss: 2.8679 - yolo_layer_3_loss: 7.1117resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 11.7977 - yolo_layer_1_loss: 1.8511 - yolo_layer_2_loss: 2.8719 - yolo_layer_3_loss: 7.0747resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# 84/84 [==============================] - 88s 1s/step - loss: 11.7950 - yolo_layer_1_loss: 1.8363 - yolo_layer_2_loss: 2.8663 - yolo_layer_3_loss: 7.0923 - val_loss: 16.0928 - val_yolo_layer_1_loss: 3.9021 - val_yolo_layer_2_loss: 4.7506 - val_yolo_layer_3_loss: 7.4401
#
# Epoch 00019: loss improved from 12.58676 to 11.79498, saving model to road.h5
# Epoch 20/53
#  2/84 [..............................] - ETA: 1:34 - loss: 13.0938 - yolo_layer_1_loss: 3.2529 - yolo_layer_2_loss: 3.3237 - yolo_layer_3_loss: 6.5172resizing:  288 288
# 27/84 [========>.....................] - ETA: 55s - loss: 11.9364 - yolo_layer_1_loss: 1.3038 - yolo_layer_2_loss: 3.1754 - yolo_layer_3_loss: 7.4572resizing:  384 384
# 38/84 [============>.................] - ETA: 46s - loss: 12.4352 - yolo_layer_1_loss: 1.5652 - yolo_layer_2_loss: 3.4029 - yolo_layer_3_loss: 7.4671resizing:  384 384
# 42/84 [==============>...............] - ETA: 42s - loss: 12.5241 - yolo_layer_1_loss: 1.6352 - yolo_layer_2_loss: 3.4710 - yolo_layer_3_loss: 7.4179resizing:  448 448
# 84/84 [==============================] - 93s 1s/step - loss: 11.7047 - yolo_layer_1_loss: 1.9178 - yolo_layer_2_loss: 2.9020 - yolo_layer_3_loss: 6.8849 - val_loss: 13.3670 - val_yolo_layer_1_loss: 1.6633 - val_yolo_layer_2_loss: 3.1543 - val_yolo_layer_3_loss: 8.5495
#
# Epoch 00021: loss improved from 11.79498 to 11.70469, saving model to road.h5
# Epoch 22/53
# 10/84 [==>...........................] - ETA: 1:26 - loss: 13.3992 - yolo_layer_1_loss: 2.6649 - yolo_layer_2_loss: 3.4964 - yolo_layer_3_loss: 7.2379resizing:  288 288
# 16/84 [====>.........................] - ETA: 1:19 - loss: 12.8324 - yolo_layer_1_loss: 2.3888 - yolo_layer_2_loss: 3.5487 - yolo_layer_3_loss: 6.8949resizing:  320 320
# 28/84 [=========>....................] - ETA: 59s - loss: 12.0867 - yolo_layer_1_loss: 1.8901 - yolo_layer_2_loss: 3.2200 - yolo_layer_3_loss: 6.9765 resizing:  416 416
# 38/84 [============>.................] - ETA: 48s - loss: 11.6235 - yolo_layer_1_loss: 1.7293 - yolo_layer_2_loss: 2.9684 - yolo_layer_3_loss: 6.9258resizing:  448 448
# 45/84 [===============>..............] - ETA: 42s - loss: 11.9622 - yolo_layer_1_loss: 2.0336 - yolo_layer_2_loss: 3.2134 - yolo_layer_3_loss: 6.7152resizing:  384 384
# 55/84 [==================>...........] - ETA: 33s - loss: 12.2983 - yolo_layer_1_loss: 2.1654 - yolo_layer_2_loss: 3.3760 - yolo_layer_3_loss: 6.7569resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# 83/84 [============================>.] - ETA: 1s - loss: 12.2314 - yolo_layer_1_loss: 2.1251 - yolo_layer_2_loss: 3.2622 - yolo_layer_3_loss: 6.8440resizing:  352 352
# 84/84 [==============================] - 103s 1s/step - loss: 12.2390 - yolo_layer_1_loss: 2.1393 - yolo_layer_2_loss: 3.2641 - yolo_layer_3_loss: 6.8356 - val_loss: 12.7492 - val_yolo_layer_1_loss: 1.1644 - val_yolo_layer_2_loss: 2.3854 - val_yolo_layer_3_loss: 9.1994
#
# Epoch 00022: loss did not improve from 11.70469
# Epoch 23/53
# resizing:  320 320
#  1/84 [..............................] - ETA: 1:54 - loss: 14.3768 - yolo_layer_1_loss: 5.7968 - yolo_layer_2_loss: 4.0642 - yolo_layer_3_loss: 4.5158resizing:  288 288
#  3/84 [>.............................] - ETA: 1:50 - loss: 11.8176 - yolo_layer_1_loss: 3.2338 - yolo_layer_2_loss: 3.2738 - yolo_layer_3_loss: 5.3100resizing:  384 384
# 27/84 [========>.....................] - ETA: 1:08 - loss: 12.7351 - yolo_layer_1_loss: 2.4455 - yolo_layer_2_loss: 3.6029 - yolo_layer_3_loss: 6.6867resizing:  352 352
# resizing:  352 352
# 32/84 [==========>...................] - ETA: 1:01 - loss: 12.6039 - yolo_layer_1_loss: 2.3982 - yolo_layer_2_loss: 3.4957 - yolo_layer_3_loss: 6.7100resizing:  288 288
# 55/84 [==================>...........] - ETA: 31s - loss: 12.0579 - yolo_layer_1_loss: 1.7885 - yolo_layer_2_loss: 3.1314 - yolo_layer_3_loss: 7.1380resizing:  352 352
# resizing:  320 320
# 62/84 [=====================>........] - ETA: 23s - loss: 11.9195 - yolo_layer_1_loss: 1.7586 - yolo_layer_2_loss: 3.1233 - yolo_layer_3_loss: 7.0377resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 11.9888 - yolo_layer_1_loss: 1.7887 - yolo_layer_2_loss: 3.1827 - yolo_layer_3_loss: 7.0174resizing:  320 320
# 84/84 [==============================] - 96s 1s/step - loss: 12.0121 - yolo_layer_1_loss: 1.8337 - yolo_layer_2_loss: 3.1829 - yolo_layer_3_loss: 6.9955 - val_loss: 15.5747 - val_yolo_layer_1_loss: 1.2379 - val_yolo_layer_2_loss: 4.2785 - val_yolo_layer_3_loss: 10.0583
#
# Epoch 00023: loss did not improve from 11.70469
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 24/53
# 11/84 [==>...........................] - ETA: 1:47 - loss: 12.5624 - yolo_layer_1_loss: 2.0007 - yolo_layer_2_loss: 3.6141 - yolo_layer_3_loss: 6.9475resizing:  384 384
# 12/84 [===>..........................] - ETA: 1:46 - loss: 12.5823 - yolo_layer_1_loss: 2.1445 - yolo_layer_2_loss: 3.5933 - yolo_layer_3_loss: 6.8445resizing:  320 320
# 15/84 [====>.........................] - ETA: 1:41 - loss: 12.6867 - yolo_layer_1_loss: 2.4102 - yolo_layer_2_loss: 3.8113 - yolo_layer_3_loss: 6.4652resizing:  384 384
# 28/84 [=========>....................] - ETA: 1:16 - loss: 11.8090 - yolo_layer_1_loss: 1.9878 - yolo_layer_2_loss: 3.4200 - yolo_layer_3_loss: 6.4011resizing:  320 320
# 45/84 [===============>..............] - ETA: 48s - loss: 11.6816 - yolo_layer_1_loss: 1.8817 - yolo_layer_2_loss: 3.2362 - yolo_layer_3_loss: 6.5637resizing:  416 416
# 46/84 [===============>..............] - ETA: 46s - loss: 11.6203 - yolo_layer_1_loss: 1.8415 - yolo_layer_2_loss: 3.2084 - yolo_layer_3_loss: 6.5704resizing:  384 384
# 56/84 [===================>..........] - ETA: 33s - loss: 11.6671 - yolo_layer_1_loss: 1.8480 - yolo_layer_2_loss: 3.2583 - yolo_layer_3_loss: 6.5608resizing:  384 384
# 67/84 [======================>.......] - ETA: 20s - loss: 11.7104 - yolo_layer_1_loss: 1.9019 - yolo_layer_2_loss: 3.2921 - yolo_layer_3_loss: 6.5165resizing:  448 448
# 68/84 [=======================>......] - ETA: 18s - loss: 11.6942 - yolo_layer_1_loss: 1.9133 - yolo_layer_2_loss: 3.2834 - yolo_layer_3_loss: 6.4975resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 11.4754 - yolo_layer_1_loss: 1.9317 - yolo_layer_2_loss: 3.1718 - yolo_layer_3_loss: 6.3719resizing:  288 288
# resizing:  416 416
# 84/84 [==============================] - 104s 1s/step - loss: 11.5155 - yolo_layer_1_loss: 1.9783 - yolo_layer_2_loss: 3.1713 - yolo_layer_3_loss: 6.3659 - val_loss: 13.2901 - val_yolo_layer_1_loss: 1.4878 - val_yolo_layer_2_loss: 3.5232 - val_yolo_layer_3_loss: 8.2790
#
# Epoch 00024: loss improved from 11.70469 to 11.51553, saving model to road.h5
# Epoch 25/53
#  7/84 [=>............................] - ETA: 1:53 - loss: 12.4161 - yolo_layer_1_loss: 2.7003 - yolo_layer_2_loss: 3.4366 - yolo_layer_3_loss: 6.2792resizing:  352 352
#  8/84 [=>............................] - ETA: 1:45 - loss: 12.1572 - yolo_layer_1_loss: 2.5333 - yolo_layer_2_loss: 3.4814 - yolo_layer_3_loss: 6.1425resizing:  288 288
# 27/84 [========>.....................] - ETA: 57s - loss: 10.4922 - yolo_layer_1_loss: 1.3306 - yolo_layer_2_loss: 2.4718 - yolo_layer_3_loss: 6.6897resizing:  320 320
# resizing:  448 448
# ...
# 83/84 [============================>.] - ETA: 1s - loss: 10.0754 - yolo_layer_1_loss: 1.3055 - yolo_layer_2_loss: 2.4403 - yolo_layer_3_loss: 6.3296resizing:  288 288
# 84/84 [==============================] - 95s 1s/step - loss: 10.0794 - yolo_layer_1_loss: 1.3103 - yolo_layer_2_loss: 2.4390 - yolo_layer_3_loss: 6.3301 - val_loss: 13.1886 - val_yolo_layer_1_loss: 1.7195 - val_yolo_layer_2_loss: 3.2644 - val_yolo_layer_3_loss: 8.2047
#
# Epoch 00042: loss improved from 10.14634 to 10.07943, saving model to road.h5
# Epoch 43/53
#  4/84 [>.............................] - ETA: 1:47 - loss: 10.5390 - yolo_layer_1_loss: 2.2159 - yolo_layer_2_loss: 2.2865 - yolo_layer_3_loss: 6.0366resizing:  288 288
# 10/84 [==>...........................] - ETA: 1:40 - loss: 8.8570 - yolo_layer_1_loss: 1.3646 - yolo_layer_2_loss: 2.0510 - yolo_layer_3_loss: 5.4414resizing:  288 288
# 12/84 [===>..........................] - ETA: 1:37 - loss: 9.4833 - yolo_layer_1_loss: 1.4669 - yolo_layer_2_loss: 2.4372 - yolo_layer_3_loss: 5.5791resizing:  448 448
# 30/84 [=========>....................] - ETA: 1:07 - loss: 10.7071 - yolo_layer_1_loss: 1.5958 - yolo_layer_2_loss: 2.7673 - yolo_layer_3_loss: 6.3440resizing:  384 384
# 35/84 [===========>..................] - ETA: 1:03 - loss: 11.0901 - yolo_layer_1_loss: 1.7940 - yolo_layer_2_loss: 3.1120 - yolo_layer_3_loss: 6.1841resizing:  448 448
# 45/84 [===============>..............] - ETA: 50s - loss: 10.8147 - yolo_layer_1_loss: 1.7427 - yolo_layer_2_loss: 3.1002 - yolo_layer_3_loss: 5.9717resizing:  320 320
# 61/84 [====================>.........] - ETA: 29s - loss: 10.7657 - yolo_layer_1_loss: 1.8264 - yolo_layer_2_loss: 3.0415 - yolo_layer_3_loss: 5.8978resizing:  384 384
# 64/84 [=====================>........] - ETA: 25s - loss: 10.7978 - yolo_layer_1_loss: 1.7869 - yolo_layer_2_loss: 3.0279 - yolo_layer_3_loss: 5.9830resizing:  384 384
# 65/84 [======================>.......] - ETA: 23s - loss: 10.7380 - yolo_layer_1_loss: 1.7822 - yolo_layer_2_loss: 3.0032 - yolo_layer_3_loss: 5.9526resizing:  352 352
# 83/84 [============================>.] - ETA: 1s - loss: 10.5296 - yolo_layer_1_loss: 1.6272 - yolo_layer_2_loss: 2.8930 - yolo_layer_3_loss: 6.0094resizing:  288 288
# resizing:  320 320
# 84/84 [==============================] - 104s 1s/step - loss: 10.5335 - yolo_layer_1_loss: 1.6272 - yolo_layer_2_loss: 2.8765 - yolo_layer_3_loss: 6.0299 - val_loss: 12.8738 - val_yolo_layer_1_loss: 1.5968 - val_yolo_layer_2_loss: 2.2331 - val_yolo_layer_3_loss: 9.0440
#
# Epoch 00043: loss did not improve from 10.07943
# Epoch 44/53
# 12/84 [===>..........................] - ETA: 1:03 - loss: 9.4950 - yolo_layer_1_loss: 1.0147 - yolo_layer_2_loss: 1.8993 - yolo_layer_3_loss: 6.5810resizing:  384 384
# 14/84 [====>.........................] - ETA: 1:01 - loss: 10.0355 - yolo_layer_1_loss: 1.2909 - yolo_layer_2_loss: 2.1357 - yolo_layer_3_loss: 6.6089resizing:  288 288
# 35/84 [===========>..................] - ETA: 42s - loss: 10.2663 - yolo_layer_1_loss: 1.2405 - yolo_layer_2_loss: 2.2320 - yolo_layer_3_loss: 6.7938resizing:  288 288
# 40/84 [=============>................] - ETA: 38s - loss: 10.1667 - yolo_layer_1_loss: 1.1647 - yolo_layer_2_loss: 2.2689 - yolo_layer_3_loss: 6.7330resizing:  352 352
# 42/84 [==============>...............] - ETA: 36s - loss: 10.0158 - yolo_layer_1_loss: 1.1221 - yolo_layer_2_loss: 2.2344 - yolo_layer_3_loss: 6.6593resizing:  416 416
# 55/84 [==================>...........] - ETA: 26s - loss: 9.8289 - yolo_layer_1_loss: 1.0459 - yolo_layer_2_loss: 2.2593 - yolo_layer_3_loss: 6.5237resizing:  448 448
# 56/84 [===================>..........] - ETA: 25s - loss: 9.8451 - yolo_layer_1_loss: 1.0714 - yolo_layer_2_loss: 2.2542 - yolo_layer_3_loss: 6.5195resizing:  448 448
# 65/84 [======================>.......] - ETA: 18s - loss: 10.0465 - yolo_layer_1_loss: 1.1929 - yolo_layer_2_loss: 2.4318 - yolo_layer_3_loss: 6.4217resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 10.2645 - yolo_layer_1_loss: 1.4245 - yolo_layer_2_loss: 2.6187 - yolo_layer_3_loss: 6.2213resizing:  320 320
# 84/84 [==============================] - 95s 1s/step - loss: 10.2890 - yolo_layer_1_loss: 1.4195 - yolo_layer_2_loss: 2.6207 - yolo_layer_3_loss: 6.2488 - val_loss: 13.2101 - val_yolo_layer_1_loss: 2.7185 - val_yolo_layer_2_loss: 2.2277 - val_yolo_layer_3_loss: 8.2639
#
# Epoch 00044: loss did not improve from 10.07943
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 45/53
#  1/84 [..............................] - ETA: 2:03 - loss: 8.9697 - yolo_layer_1_loss: 2.0812 - yolo_layer_2_loss: 2.3721 - yolo_layer_3_loss: 4.5164resizing:  352 352
#  9/84 [==>...........................] - ETA: 1:50 - loss: 9.5156 - yolo_layer_1_loss: 1.4958 - yolo_layer_2_loss: 2.6517 - yolo_layer_3_loss: 5.3681resizing:  384 384
# 15/84 [====>.........................] - ETA: 1:32 - loss: 9.9475 - yolo_layer_1_loss: 1.7366 - yolo_layer_2_loss: 2.3588 - yolo_layer_3_loss: 5.8520 resizing:  288 288
# 34/84 [===========>..................] - ETA: 56s - loss: 9.4219 - yolo_layer_1_loss: 1.3316 - yolo_layer_2_loss: 2.1422 - yolo_layer_3_loss: 5.9481resizing:  288 288
# 37/84 [============>.................] - ETA: 52s - loss: 9.4744 - yolo_layer_1_loss: 1.2281 - yolo_layer_2_loss: 2.1737 - yolo_layer_3_loss: 6.0725resizing:  448 448
# 40/84 [=============>................] - ETA: 48s - loss: 9.5963 - yolo_layer_1_loss: 1.2146 - yolo_layer_2_loss: 2.2154 - yolo_layer_3_loss: 6.1663resizing:  448 448
# 57/84 [===================>..........] - ETA: 30s - loss: 9.9898 - yolo_layer_1_loss: 1.3417 - yolo_layer_2_loss: 2.3945 - yolo_layer_3_loss: 6.2536resizing:  416 416
# 60/84 [====================>.........] - ETA: 27s - loss: 9.9478 - yolo_layer_1_loss: 1.3711 - yolo_layer_2_loss: 2.3995 - yolo_layer_3_loss: 6.1772resizing:  384 384
# 66/84 [======================>.......] - ETA: 21s - loss: 10.0431 - yolo_layer_1_loss: 1.4434 - yolo_layer_2_loss: 2.4999 - yolo_layer_3_loss: 6.0998resizing:  320 320
# 83/84 [============================>.] - ETA: 1s - loss: 9.9117 - yolo_layer_1_loss: 1.3225 - yolo_layer_2_loss: 2.4220 - yolo_layer_3_loss: 6.1673resizing:  352 352
# resizing:  416 416
# 84/84 [==============================] - 100s 1s/step - loss: 9.9266 - yolo_layer_1_loss: 1.3153 - yolo_layer_2_loss: 2.4268 - yolo_layer_3_loss: 6.1846 - val_loss: 13.3629 - val_yolo_layer_1_loss: 1.7874 - val_yolo_layer_2_loss: 3.7622 - val_yolo_layer_3_loss: 7.8134
#
# Epoch 00045: loss improved from 10.07943 to 9.92663, saving model to road.h5
# Epoch 46/53
#  5/84 [>.............................] - ETA: 1:13 - loss: 10.5785 - yolo_layer_1_loss: 1.5837 - yolo_layer_2_loss: 2.7012 - yolo_layer_3_loss: 6.2935resizing:  288 288
# 13/84 [===>..........................] - ETA: 1:12 - loss: 10.6498 - yolo_layer_1_loss: 1.6660 - yolo_layer_2_loss: 2.7412 - yolo_layer_3_loss: 6.2425resizing:  352 352
# 27/84 [========>.....................] - ETA: 55s - loss: 9.4525 - yolo_layer_1_loss: 0.9634 - yolo_layer_2_loss: 2.2004 - yolo_layer_3_loss: 6.2887resizing:  416 416
# resizing:  384 384
# 44/84 [==============>...............] - ETA: 42s - loss: 9.7817 - yolo_layer_1_loss: 1.0541 - yolo_layer_2_loss: 2.5424 - yolo_layer_3_loss: 6.1852resizing:  352 352
# 55/84 [==================>...........] - ETA: 31s - loss: 9.9813 - yolo_layer_1_loss: 1.2384 - yolo_layer_2_loss: 2.5688 - yolo_layer_3_loss: 6.1741 resizing:  352 352
# 64/84 [=====================>........] - ETA: 21s - loss: 9.8730 - yolo_layer_1_loss: 1.1813 - yolo_layer_2_loss: 2.5610 - yolo_layer_3_loss: 6.1307resizing:  352 352
# 67/84 [======================>.......] - ETA: 18s - loss: 9.9055 - yolo_layer_1_loss: 1.1724 - yolo_layer_2_loss: 2.5687 - yolo_layer_3_loss: 6.1643resizing:  416 416
# 83/84 [============================>.] - ETA: 1s - loss: 10.0148 - yolo_layer_1_loss: 1.2320 - yolo_layer_2_loss: 2.6279 - yolo_layer_3_loss: 6.1549resizing:  288 288
# 84/84 [==============================] - 95s 1s/step - loss: 10.0512 - yolo_layer_1_loss: 1.2379 - yolo_layer_2_loss: 2.6262 - yolo_layer_3_loss: 6.1870 - val_loss: 15.6808 - val_yolo_layer_1_loss: 2.8562 - val_yolo_layer_2_loss: 4.3281 - val_yolo_layer_3_loss: 8.4965
#
# Epoch 00046: loss did not improve from 9.92663
# Epoch 47/53
#  4/84 [>.............................] - ETA: 1:48 - loss: 13.3430 - yolo_layer_1_loss: 2.9996 - yolo_layer_2_loss: 4.1914 - yolo_layer_3_loss: 6.1521resizing:  384 384
# 12/84 [===>..........................] - ETA: 1:37 - loss: 11.2419 - yolo_layer_1_loss: 2.1320 - yolo_layer_2_loss: 3.0271 - yolo_layer_3_loss: 6.0827resizing:  384 384
# 15/84 [====>.........................] - ETA: 1:31 - loss: 11.1236 - yolo_layer_1_loss: 1.8482 - yolo_layer_2_loss: 3.2079 - yolo_layer_3_loss: 6.0676resizing:  384 384
# 28/84 [=========>....................] - ETA: 1:09 - loss: 10.6623 - yolo_layer_1_loss: 1.7231 - yolo_layer_2_loss: 2.8733 - yolo_layer_3_loss: 6.0659resizing:  416 416
# 33/84 [==========>...................] - ETA: 1:02 - loss: 10.4423 - yolo_layer_1_loss: 1.6671 - yolo_layer_2_loss: 2.7863 - yolo_layer_3_loss: 5.9889resizing:  288 288
# 42/84 [==============>...............] - ETA: 52s - loss: 10.3220 - yolo_layer_1_loss: 1.6295 - yolo_layer_2_loss: 2.7536 - yolo_layer_3_loss: 5.9388resizing:  416 416
# 55/84 [==================>...........] - ETA: 34s - loss: 10.2632 - yolo_layer_1_loss: 1.5133 - yolo_layer_2_loss: 2.6627 - yolo_layer_3_loss: 6.0872resizing:  448 448
# resizing:  384 384
# 69/84 [=======================>......] - ETA: 17s - loss: 10.2035 - yolo_layer_1_loss: 1.6279 - yolo_layer_2_loss: 2.6257 - yolo_layer_3_loss: 5.9499resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 10.3017 - yolo_layer_1_loss: 1.6659 - yolo_layer_2_loss: 2.6778 - yolo_layer_3_loss: 5.9580resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# 84/84 [==============================] - 104s 1s/step - loss: 10.3191 - yolo_layer_1_loss: 1.6662 - yolo_layer_2_loss: 2.6915 - yolo_layer_3_loss: 5.9613 - val_loss: 13.3807 - val_yolo_layer_1_loss: 1.5718 - val_yolo_layer_2_loss: 3.0366 - val_yolo_layer_3_loss: 8.7724
#
# Epoch 00047: loss did not improve from 9.92663
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 48/53
# 27/84 [========>.....................] - ETA: 1:22 - loss: 11.9160 - yolo_layer_1_loss: 2.6756 - yolo_layer_2_loss: 3.3747 - yolo_layer_3_loss: 5.8657resizing:  384 384
# 38/84 [============>.................] - ETA: 1:03 - loss: 11.5142 - yolo_layer_1_loss: 2.4810 - yolo_layer_2_loss: 3.1952 - yolo_layer_3_loss: 5.8380resizing:  288 288
# 42/84 [==============>...............] - ETA: 57s - loss: 11.3390 - yolo_layer_1_loss: 2.3820 - yolo_layer_2_loss: 3.0807 - yolo_layer_3_loss: 5.8763resizing:  448 448
# 55/84 [==================>...........] - ETA: 38s - loss: 11.3346 - yolo_layer_1_loss: 2.1930 - yolo_layer_2_loss: 3.0386 - yolo_layer_3_loss: 6.1029resizing:  448 448
# 56/84 [===================>..........] - ETA: 36s - loss: 11.3240 - yolo_layer_1_loss: 2.1775 - yolo_layer_2_loss: 3.0520 - yolo_layer_3_loss: 6.0945resizing:  416 416
# 66/84 [======================>.......] - ETA: 24s - loss: 11.2403 - yolo_layer_1_loss: 2.2023 - yolo_layer_2_loss: 3.0397 - yolo_layer_3_loss: 5.9984resizing:  448 448
# 83/84 [============================>.] - ETA: 1s - loss: 11.1272 - yolo_layer_1_loss: 2.0820 - yolo_layer_2_loss: 3.1171 - yolo_layer_3_loss: 5.9282resizing:  352 352
# 84/84 [==============================] - 116s 1s/step - loss: 11.1410 - yolo_layer_1_loss: 2.0974 - yolo_layer_2_loss: 3.0996 - yolo_layer_3_loss: 5.9440 - val_loss: 14.8354 - val_yolo_layer_1_loss: 1.6716 - val_yolo_layer_2_loss: 4.0022 - val_yolo_layer_3_loss: 9.1616
#
# Epoch 00048: loss did not improve from 9.92663
# Epoch 49/53
#  1/84 [..............................] - ETA: 2:03 - loss: 12.9630 - yolo_layer_1_loss: 4.1267 - yolo_layer_2_loss: 2.7523 - yolo_layer_3_loss: 6.0840resizing:  384 384
#  6/84 [=>............................] - ETA: 1:54 - loss: 12.8433 - yolo_layer_1_loss: 2.1094 - yolo_layer_2_loss: 4.6846 - yolo_layer_3_loss: 6.0493resizing:  352 352
# 15/84 [====>.........................] - ETA: 1:33 - loss: 11.7574 - yolo_layer_1_loss: 2.0816 - yolo_layer_2_loss: 3.5930 - yolo_layer_3_loss: 6.0828resizing:  384 384
# 27/84 [========>.....................] - ETA: 1:10 - loss: 10.9454 - yolo_layer_1_loss: 1.7770 - yolo_layer_2_loss: 3.2279 - yolo_layer_3_loss: 5.9405resizing:  288 288
# 33/84 [==========>...................] - ETA: 1:00 - loss: 10.8525 - yolo_layer_1_loss: 1.6930 - yolo_layer_2_loss: 3.0717 - yolo_layer_3_loss: 6.0878resizing:  448 448
# 40/84 [=============>................] - ETA: 49s - loss: 10.5613 - yolo_layer_1_loss: 1.6039 - yolo_layer_2_loss: 2.8183 - yolo_layer_3_loss: 6.1391resizing:  384 384
# 55/84 [==================>...........] - ETA: 33s - loss: 10.5178 - yolo_layer_1_loss: 1.6190 - yolo_layer_2_loss: 2.7960 - yolo_layer_3_loss: 6.1028resizing:  448 448
# 69/84 [=======================>......] - ETA: 17s - loss: 10.3300 - yolo_layer_1_loss: 1.6080 - yolo_layer_2_loss: 2.7264 - yolo_layer_3_loss: 5.9956resizing:  416 416
# 72/84 [========================>.....] - ETA: 14s - loss: 10.5157 - yolo_layer_1_loss: 1.7419 - yolo_layer_2_loss: 2.7679 - yolo_layer_3_loss: 6.0059resizing:  288 288
# 83/84 [============================>.] - ETA: 1s - loss: 10.5115 - yolo_layer_1_loss: 1.7254 - yolo_layer_2_loss: 2.7548 - yolo_layer_3_loss: 6.0313resizing:  448 448
# 84/84 [==============================] - 104s 1s/step - loss: 10.4635 - yolo_layer_1_loss: 1.7051 - yolo_layer_2_loss: 2.7428 - yolo_layer_3_loss: 6.0156 - val_loss: 12.7415 - val_yolo_layer_1_loss: 1.8325 - val_yolo_layer_2_loss: 3.1562 - val_yolo_layer_3_loss: 7.7528
#
# Epoch 00049: loss did not improve from 9.92663
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# Epoch 50/53
#  1/84 [..............................] - ETA: 1:10 - loss: 7.4839 - yolo_layer_1_loss: 0.6685 - yolo_layer_2_loss: 1.4382 - yolo_layer_3_loss: 5.3772resizing:  288 288
#  5/84 [>.............................] - ETA: 1:06 - loss: 8.7133 - yolo_layer_1_loss: 0.6590 - yolo_layer_2_loss: 2.1426 - yolo_layer_3_loss: 5.9117resizing:  288 288
#  7/84 [=>............................] - ETA: 1:04 - loss: 8.6957 - yolo_layer_1_loss: 0.4767 - yolo_layer_2_loss: 1.9002 - yolo_layer_3_loss: 6.3188resizing:  448 448
# 27/84 [========>.....................] - ETA: 1:02 - loss: 10.7853 - yolo_layer_1_loss: 1.2692 - yolo_layer_2_loss: 2.8635 - yolo_layer_3_loss: 6.6525resizing:  320 320
# 33/84 [==========>...................] - ETA: 55s - loss: 10.5663 - yolo_layer_1_loss: 1.1687 - yolo_layer_2_loss: 2.7996 - yolo_layer_3_loss: 6.5980resizing:  416 416
# 36/84 [===========>..................] - ETA: 51s - loss: 10.5824 - yolo_layer_1_loss: 1.1798 - yolo_layer_2_loss: 2.8081 - yolo_layer_3_loss: 6.5945resizing:  384 384
# 55/84 [==================>...........] - ETA: 31s - loss: 10.5787 - yolo_layer_1_loss: 1.1586 - yolo_layer_2_loss: 2.8053 - yolo_layer_3_loss: 6.6148resizing:  384 384
# 62/84 [=====================>........] - ETA: 24s - loss: 10.4780 - yolo_layer_1_loss: 1.2195 - yolo_layer_2_loss: 2.8000 - yolo_layer_3_loss: 6.4585resizing:  416 416
# 68/84 [=======================>......] - ETA: 17s - loss: 10.6039 - yolo_layer_1_loss: 1.2680 - yolo_layer_2_loss: 2.7907 - yolo_layer_3_loss: 6.5453resizing:  384 384
# 83/84 [============================>.] - ETA: 1s - loss: 10.4467 - yolo_layer_1_loss: 1.3952 - yolo_layer_2_loss: 2.6929 - yolo_layer_3_loss: 6.3586resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# 84/84 [==============================] - 98s 1s/step - loss: 10.4756 - yolo_layer_1_loss: 1.3997 - yolo_layer_2_loss: 2.7002 - yolo_layer_3_loss: 6.3757 - val_loss: 14.3853 - val_yolo_layer_1_loss: 1.8542 - val_yolo_layer_2_loss: 3.8760 - val_yolo_layer_3_loss: 8.6550
#
# Epoch 00050: loss did not improve from 9.92663
# Epoch 00050: early stopping
# pothole: 0.6010
# mAP: 0.6010

# %% [markdown]
# ## Predict Image

# %%
import os
from keras.models import load_model
# config_path  = 'config.json'
# with open(config_path) as config_buffer:    
#     config = json.load(config_buffer)
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# infer_model = load_model(config['train']['saved_weights_name'])
infer_model = load_model('/content/drive/My Drive/ML/pothole_detection/road.h5')
os.chdir('keras-yolo3')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-13a2aa8aa305> in <module>()
#       7 # infer_model = load_model(config['train']['saved_weights_name'])
#       8 infer_model = load_model('/content/drive/My Drive/ML/pothole_detection/road.h5')
# ----> 9 os.chdir('keras-yolo3')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'keras-yolo3'

# %%
# %%time


import os
import argparse
import json
import cv2
from utils.utils import get_yolo_boxes, makedirs
from utils.bbox import draw_boxes
import matplotlib.pyplot as plt

from tqdm import tqdm
import numpy as np

import time
from urllib.request import urlopen

def url_to_image(url, readFlag=cv2.IMREAD_COLOR):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    resp = urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, readFlag)

    # return the image
    return image


input_path   = '../drive/My Drive/ML/pothole_detection/test/'
# input_path =   'https://i.dailymail.co.uk/i/pix/2014/03/03/article-2572043-1BFE7DCF00000578-273_634x753.jpg'
output_path  =  '../drive/My Drive/ML/output/'



makedirs(output_path)

 
net_h, net_w = 416, 416 # a multiple of 32, the smaller the faster
obj_thresh, nms_thresh = 0.5, 0.45

image_paths = []

if os.path.isdir(input_path): 
    for inp_file in os.listdir(input_path):
        image_paths += [input_path + inp_file]
else:
    image_paths += [input_path]

image_paths = [inp_file for inp_file in image_paths if (inp_file[-4:] in ['.jpg', '.png', 'JPEG'])]

print('test', image_paths)
# the main loop
for image_path in image_paths:
    start = time.time()
    image = cv2.imread(image_path)
    # image = url_to_image(image_path)
    
    # predict the bounding boxes
    boxes = get_yolo_boxes(infer_model, [image], net_h, net_w, config['model']['anchors'], obj_thresh, nms_thresh)[0]

    # draw bounding boxes on the image using labels
    draw_boxes(image, boxes, config['model']['labels'], obj_thresh) 
    print('detection time', time.time() - start)
    # write the image with bounding boxes to file
    cv2.imwrite(output_path + image_path.split('/')[-1], np.uint8(image))   
       
    plt.figure(figsize=(15, 15))
    plt.axis('off')
    plt.imshow(image)
    plt.show()

# %% [markdown]
# ## Predict Video
